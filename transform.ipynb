# %%
import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import unicodedata
import re

# %%
def normalize_column(col_name):
    # Converter para minúsculas
    col_name = col_name.lower()
    
    # Remover acentos
    col_name = ''.join(
        c for c in unicodedata.normalize('NFD', col_name)
        if unicodedata.category(c) != 'Mn'
    )
    
    # Substituir espaços e caracteres especiais por underscores
    col_name = re.sub(r'\s+', '_', col_name)  # Espaços
    col_name = re.sub(r'[^\w_]', '', col_name)  # Remover caracteres não alfanuméricos
    
    return col_name

# %%
def get_csv(path):
    try:
        pd.read_excel(path, skip)

# %%
print(pmc_df.head())
print(pmc_df.info())

print(pmvg_df.head())
print(pmvg_df.info())
# Out:
#                                substancia                cnpj  \
# 0  21-ACETATO DE DEXAMETASONA;CLOTRIMAZOL  18.459.628/0001-15
# 1                              ABATACEPTE  56.998.982/0001-07
# 2                              ABATACEPTE  56.998.982/0001-07
# 3                            ABEMACICLIBE  43.940.618/0001-44
# 4                            ABEMACICLIBE  43.940.618/0001-44
#
#                               laboratorio     codigo_ggrem       registro  \
# 0                              BAYER S.A.  538912020009303  1705600230032
# 1  BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA  505107701157215  1018003900019
# 2  BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA  505113100020505  1018003900078
# 3                ELI LILLY DO BRASIL LTDA  507619060021902  1126001990018
# 4                ELI LILLY DO BRASIL LTDA  507619060022102  1126001990034
#
#            ean_1       ean_2       ean_3     produto  \
# 0  7891106000956      -           -       BAYCUTEN N
# 1  7896016806469      -           -          ORENCIA
# 2  7896016808197      -           -          ORENCIA
# 3  7896382708442      -           -        VERZENIOS
# 4  7896382708466      -           -        VERZENIOS
#
#                                         apresentacao  ... pmc_22_alc  \
# 0     10 MG/G + 0,443 MG/G CREM DERM CT BG AL X 40 G  ...      45.70
# 1   250 MG PO LIOF SOL INJ CT 1 FA + SER DESCARTÁVEL  ...        NaN
# 2  125 MG/ML SOL INJ SC CT 4 SER PREENC VD TRANS ...  ...   11381.34
# 3                     50 MG COM REV CT BL AL AL X 30  ...    4812.49
# 4                    100 MG COM REV CT BL AL AL X 30  ...    9624.92
#
#   restricao_hospitalar  cap  confaz_87  icms_0 analise_recursal  \
# 0                  Não  Não        Não     Não              NaN
# 1                  Sim  Sim        Não     Não              NaN
# 2                  Não  Sim        Sim     Não              NaN
# 3                  Não  Não        Não     Não              NaN
# 4                  Não  Não        Não     Não              NaN
#
#   lista_de_concessao_de_credito_tributario_piscofins comercializacao_2022  \
# 0                                           Negativa                  Sim
# 1                                           Positiva                  Sim
# 2                                           Positiva                  Sim
# 3                                           Negativa                  Sim
# 4                                           Negativa                  Sim
#
#             tarja destinacao_comercial_
# 0          - (*)                    Sim
# 1  Tarja Vermelha                   Sim
# 2          - (*)                    Sim
# 3  Tarja Vermelha                   Não
# 4  Tarja Vermelha                   Não
#
# [5 rows x 64 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24873 entries, 0 to 24872
# Data columns (total 64 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   substancia                                          24873 non-null  object
#  1   cnpj                                                24873 non-null  object
#  2   laboratorio                                         24873 non-null  object
#  3   codigo_ggrem                                        24873 non-null  int64
#  4   registro                                            24873 non-null  int64
#  5   ean_1                                               24873 non-null  object
#  6   ean_2                                               24873 non-null  object
#  7   ean_3                                               24873 non-null  object
#  8   produto                                             24873 non-null  object
#  9   apresentacao                                        24873 non-null  object
#  10  classe_terapeutica                                  24873 non-null  object
#  11  tipo_de_produto_status_do_produto                   24873 non-null  object
#  12  regime_de_preco                                     24873 non-null  object
#  13  pf_sem_impostos                                     24873 non-null  float64
#  14  pf_0                                                24873 non-null  float64
#  15  pf_12                                               24873 non-null  object
#  16  pf_12_alc                                           24873 non-null  object
#  17  pf_17                                               24873 non-null  object
#  18  pf_17_alc                                           24873 non-null  object
#  19  pf_175                                              24873 non-null  object
#  20  pf_175_alc                                          24873 non-null  object
#  21  pf_18                                               24873 non-null  object
#  22  pf_18_alc                                           24873 non-null  object
#  23  pf_19                                               24873 non-null  object
#  24  pf_19_alc                                           24873 non-null  object
#  25  pf_195                                              24873 non-null  object
#  26  pf_195_alc                                          24873 non-null  object
#  27  pf_20                                               24873 non-null  object
#  28  pf_20_alc                                           24873 non-null  object
#  29  pf_205                                              24873 non-null  object
#  30  pf_21                                               24873 non-null  object
#  31  pf_21_alc                                           24873 non-null  object
#  32  pf_22                                               24873 non-null  object
#  33  pf_22_alc                                           24873 non-null  object
#  34  pmc_sem_imposto                                     21023 non-null  float64
#  35  pmc_0                                               21026 non-null  float64
#  36  pmc_12                                              21026 non-null  object
#  37  pmc_12_alc                                          21026 non-null  object
#  38  pmc_17                                              21026 non-null  object
#  39  pmc_17_alc                                          21026 non-null  object
#  40  pmc_175                                             21026 non-null  object
#  41  pmc_175_alc                                         21026 non-null  object
#  42  pmc_18                                              21026 non-null  object
#  43  pmc_18_alc                                          21026 non-null  object
#  44  pmc_19                                              21026 non-null  object
#  45  pmc_19_alc                                          21026 non-null  object
#  46  pmc_195                                             21026 non-null  object
#  47  pmc_195_alc                                         21026 non-null  object
#  48  pmc_20                                              21026 non-null  object
#  49  pmc_20_alc                                          21026 non-null  object
#  50  pmc_205                                             21026 non-null  object
#  51  pmc_21                                              21026 non-null  object
#  52  pmc_21_alc                                          21026 non-null  object
#  53  pmc_22                                              21026 non-null  object
#  54  pmc_22_alc                                          21026 non-null  object
#  55  restricao_hospitalar                                24873 non-null  object
#  56  cap                                                 24873 non-null  object
#  57  confaz_87                                           24873 non-null  object
#  58  icms_0                                              24873 non-null  object
#  59  analise_recursal                                    117 non-null    object
#  60  lista_de_concessao_de_credito_tributario_piscofins  24873 non-null  object
#  61  comercializacao_2022                                24873 non-null  object
#  62  tarja                                               24873 non-null  object
#  63  destinacao_comercial_                               24873 non-null  object
# dtypes: float64(4), int64(2), object(58)
# memory usage: 12.1+ MB
# None
#                                substancia                cnpj  \
# 0                                     NaN                 NaN
# 1  21-ACETATO DE DEXAMETASONA;CLOTRIMAZOL  18.459.628/0001-15
# 2                              ABATACEPTE  56.998.982/0001-07
# 3                              ABATACEPTE  56.998.982/0001-07
# 4                            ABEMACICLIBE  43.940.618/0001-44
#
#                               laboratorio  codigo_ggrem      registro  \
# 0                                     NaN           NaN           NaN
# 1                              BAYER S.A.  5.389120e+14  1.705600e+12
# 2  BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA  5.051077e+14  1.018004e+12
# 3  BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA  5.051131e+14  1.018004e+12
# 4                ELI LILLY DO BRASIL LTDA  5.076191e+14  1.126002e+12
#
#            ean_1       ean_2       ean_3     produto  \
# 0            NaN         NaN         NaN         NaN
# 1  7891106000956      -           -       BAYCUTEN N
# 2  7896016806469      -           -          ORENCIA
# 3  7896016808197      -           -          ORENCIA
# 4  7896382708442      -           -        VERZENIOS
#
#                                         apresentacao  ... pmvg_22_alc  \
# 0                                                NaN  ...         NaN
# 1     10 MG/G + 0,443 MG/G CREM DERM CT BG AL X 40 G  ...       25.94
# 2   250 MG PO LIOF SOL INJ CT 1 FA + SER DESCARTÁVEL  ...     2034.37
# 3  125 MG/ML SOL INJ SC CT 4 SER PREENC VD TRANS ...  ...    6460.26*
# 4                     50 MG COM REV CT BL AL AL X 30  ...     2731.66
#
#   restricao_hospitalar  cap  confaz_87  icms_0 analise_recursal  \
# 0                  NaN  NaN        NaN     NaN              NaN
# 1                  Não  Não        Não     Não              NaN
# 2                  Sim  Sim        Não     Não              NaN
# 3                  Não  Sim        Sim     Não              NaN
# 4                  Não  Não        Não     Não              NaN
#
#   lista_de_concessao_de_credito_tributario_piscofins comercializacao_2022  \
# 0                                                NaN                  NaN
# 1                                           Negativa                  Sim
# 2                                           Positiva                  Sim
# 3                                           Positiva                  Sim
# 4                                           Negativa                  Sim
#
#             tarja destinacao_comercial_
# 0             NaN                   NaN
# 1          - (*)                    Sim
# 2  Tarja Vermelha                   Sim
# 3          - (*)                    Sim
# 4  Tarja Vermelha                   Não
#
# [5 rows x 64 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24874 entries, 0 to 24873
# Data columns (total 64 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   substancia                                          24873 non-null  object
#  1   cnpj                                                24873 non-null  object
#  2   laboratorio                                         24873 non-null  object
#  3   codigo_ggrem                                        24873 non-null  float64
#  4   registro                                            24873 non-null  float64
#  5   ean_1                                               24873 non-null  object
#  6   ean_2                                               24873 non-null  object
#  7   ean_3                                               24873 non-null  object
#  8   produto                                             24873 non-null  object
#  9   apresentacao                                        24873 non-null  object
#  10  classe_terapeutica                                  24873 non-null  object
#  11  tipo_de_produto_status_do_produto                   24873 non-null  object
#  12  regime_de_preco                                     24873 non-null  object
#  13  pf_sem_impostos                                     24873 non-null  float64
#  14  pf_0                                                24873 non-null  float64
#  15  pf_12                                               24873 non-null  object
#  16  pf_12_alc                                           24873 non-null  object
#  17  pf_17                                               24873 non-null  object
#  18  pf_17_alc                                           24873 non-null  object
#  19  pf_175                                              24873 non-null  object
#  20  pf_175_alc                                          24873 non-null  object
#  21  pf_18                                               24873 non-null  object
#  22  pf_18_alc                                           24873 non-null  object
#  23  pf_19                                               24873 non-null  object
#  24  pf_19_alc                                           24873 non-null  object
#  25  pf_195                                              24873 non-null  object
#  26  pf_195_alc                                          24873 non-null  object
#  27  pf_20                                               24873 non-null  object
#  28  pf_20_alc                                           24873 non-null  object
#  29  pf_2052                                             24873 non-null  object
#  30  pf_21                                               24873 non-null  object
#  31  pf_21_alc                                           24873 non-null  object
#  32  pf_22                                               24873 non-null  object
#  33  pf_22_alc                                           24873 non-null  object
#  34  pmvg_sem_imposto                                    24873 non-null  float64
#  35  pmvg_0                                              24873 non-null  float64
#  36  pmvg_12                                             24873 non-null  object
#  37  pmvg_12_alc                                         24873 non-null  object
#  38  pmvg_17                                             24873 non-null  object
#  39  pmvg_17_alc                                         24873 non-null  object
#  40  pmvg_175                                            24873 non-null  object
#  41  pmvg_175_alc                                        24873 non-null  object
#  42  pmvg_18                                             24873 non-null  object
#  43  pmvg_18_alc                                         24873 non-null  object
#  44  pmvg_19                                             24873 non-null  object
#  45  pmvg_19_alc                                         24873 non-null  object
#  46  pmvg_195                                            24873 non-null  object
#  47  pmvg_195_alc                                        24873 non-null  object
#  48  pmvg_20                                             24873 non-null  object
#  49  pmvg_20_alc                                         24873 non-null  object
#  50  pmvg_205                                            24873 non-null  object
#  51  pmvg_21                                             24873 non-null  object
#  52  pmvg_21_alc                                         24873 non-null  object
#  53  pmvg_22                                             24873 non-null  object
#  54  pmvg_22_alc                                         24873 non-null  object
#  55  restricao_hospitalar                                24873 non-null  object
#  56  cap                                                 24873 non-null  object
#  57  confaz_87                                           24873 non-null  object
#  58  icms_0                                              24873 non-null  object
#  59  analise_recursal                                    117 non-null    object
#  60  lista_de_concessao_de_credito_tributario_piscofins  24873 non-null  object
#  61  comercializacao_2022                                24873 non-null  object
#  62  tarja                                               24873 non-null  object
#  63  destinacao_comercial_                               24873 non-null  object
# dtypes: float64(6), object(58)
# memory usage: 12.1+ MB
# None

# %%
def format_data_types(df):
    # Colunas de identificação
    df['cnpj'] = df['cnpj'].astype(str)
    df['registro'] = df['registro'].astype(str)
    df['codigo_ggrem'] = df['codigo_ggrem'].astype(str)
    
    # Colunas EAN: Tratá-las como strings para preservar zeros à esquerda
    df['ean_1'] = df['ean_1'].astype(str)
    df['ean_2'] = df['ean_2'].astype(str)
    df['ean_3'] = df['ean_3'].astype(str)
    
    # Colunas numéricas: Remover vírgulas e converter para float
    numeric_columns = [col for col in df.columns if 'pmc' in col or 'pmvg' in col]
    for col in numeric_columns:
        df[col] = df[col].replace({'-': np.nan, ',': '.'}, regex=True)
        df[col] = pd.to_numeric(df[col], errors='coerce')
    
    # Colunas booleanas: Converter 'Sim'/'Não' para True/False
    bool_columns = [
        'restricao_hospitalar', 'cap', 'confaz_87', 
        'icms_0', 'analise_recurcial', 'comercializacao_2022'
    ]
    for col in bool_columns:
        if col in df.columns:
            df[col] = df[col].map({'Sim': True, 'Não': False})
    
    return df

# Aplicar a formatação nos DataFrames
pmc_df = format_data_types(pmc_df)
pmvg_df = format_data_types(pmvg_df)

# %%
pmvg_df = pmvg_df.iloc[1:]

# %%
print(pmc_df.head())
print(pmc_df.info())

print(pmvg_df.head())
print(pmvg_df.info())
# Out:
#                                substancia                cnpj  \
# 0  21-ACETATO DE DEXAMETASONA;CLOTRIMAZOL  18.459.628/0001-15
# 1                              ABATACEPTE  56.998.982/0001-07
# 2                              ABATACEPTE  56.998.982/0001-07
# 3                            ABEMACICLIBE  43.940.618/0001-44
# 4                            ABEMACICLIBE  43.940.618/0001-44
#
#                               laboratorio     codigo_ggrem       registro  \
# 0                              BAYER S.A.  538912020009303  1705600230032
# 1  BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA  505107701157215  1018003900019
# 2  BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA  505113100020505  1018003900078
# 3                ELI LILLY DO BRASIL LTDA  507619060021902  1126001990018
# 4                ELI LILLY DO BRASIL LTDA  507619060022102  1126001990034
#
#            ean_1       ean_2       ean_3     produto  \
# 0  7891106000956      -           -       BAYCUTEN N
# 1  7896016806469      -           -          ORENCIA
# 2  7896016808197      -           -          ORENCIA
# 3  7896382708442      -           -        VERZENIOS
# 4  7896382708466      -           -        VERZENIOS
#
#                                         apresentacao  ... pmc_22_alc  \
# 0     10 MG/G + 0,443 MG/G CREM DERM CT BG AL X 40 G  ...      45.70
# 1   250 MG PO LIOF SOL INJ CT 1 FA + SER DESCARTÁVEL  ...        NaN
# 2  125 MG/ML SOL INJ SC CT 4 SER PREENC VD TRANS ...  ...   11381.34
# 3                     50 MG COM REV CT BL AL AL X 30  ...    4812.49
# 4                    100 MG COM REV CT BL AL AL X 30  ...    9624.92
#
#   restricao_hospitalar    cap  confaz_87  icms_0 analise_recursal  \
# 0                False  False      False   False              NaN
# 1                 True   True      False   False              NaN
# 2                False   True       True   False              NaN
# 3                False  False      False   False              NaN
# 4                False  False      False   False              NaN
#
#   lista_de_concessao_de_credito_tributario_piscofins comercializacao_2022  \
# 0                                           Negativa                 True
# 1                                           Positiva                 True
# 2                                           Positiva                 True
# 3                                           Negativa                 True
# 4                                           Negativa                 True
#
#             tarja destinacao_comercial_
# 0          - (*)                    Sim
# 1  Tarja Vermelha                   Sim
# 2          - (*)                    Sim
# 3  Tarja Vermelha                   Não
# 4  Tarja Vermelha                   Não
#
# [5 rows x 64 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24873 entries, 0 to 24872
# Data columns (total 64 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   substancia                                          24873 non-null  object
#  1   cnpj                                                24873 non-null  object
#  2   laboratorio                                         24873 non-null  object
#  3   codigo_ggrem                                        24873 non-null  object
#  4   registro                                            24873 non-null  object
#  5   ean_1                                               24873 non-null  object
#  6   ean_2                                               24873 non-null  object
#  7   ean_3                                               24873 non-null  object
#  8   produto                                             24873 non-null  object
#  9   apresentacao                                        24873 non-null  object
#  10  classe_terapeutica                                  24873 non-null  object
#  11  tipo_de_produto_status_do_produto                   24873 non-null  object
#  12  regime_de_preco                                     24873 non-null  object
#  13  pf_sem_impostos                                     24873 non-null  float64
#  14  pf_0                                                24873 non-null  float64
#  15  pf_12                                               24873 non-null  object
#  16  pf_12_alc                                           24873 non-null  object
#  17  pf_17                                               24873 non-null  object
#  18  pf_17_alc                                           24873 non-null  object
#  19  pf_175                                              24873 non-null  object
#  20  pf_175_alc                                          24873 non-null  object
#  21  pf_18                                               24873 non-null  object
#  22  pf_18_alc                                           24873 non-null  object
#  23  pf_19                                               24873 non-null  object
#  24  pf_19_alc                                           24873 non-null  object
#  25  pf_195                                              24873 non-null  object
#  26  pf_195_alc                                          24873 non-null  object
#  27  pf_20                                               24873 non-null  object
#  28  pf_20_alc                                           24873 non-null  object
#  29  pf_205                                              24873 non-null  object
#  30  pf_21                                               24873 non-null  object
#  31  pf_21_alc                                           24873 non-null  object
#  32  pf_22                                               24873 non-null  object
#  33  pf_22_alc                                           24873 non-null  object
#  34  pmc_sem_imposto                                     21023 non-null  float64
#  35  pmc_0                                               21026 non-null  float64
#  36  pmc_12                                              20715 non-null  float64
#  37  pmc_12_alc                                          20715 non-null  float64
#  38  pmc_17                                              20715 non-null  float64
#  39  pmc_17_alc                                          20715 non-null  float64
#  40  pmc_175                                             20715 non-null  float64
#  41  pmc_175_alc                                         20715 non-null  float64
#  42  pmc_18                                              20715 non-null  float64
#  43  pmc_18_alc                                          20715 non-null  float64
#  44  pmc_19                                              20715 non-null  float64
#  45  pmc_19_alc                                          20715 non-null  float64
#  46  pmc_195                                             20715 non-null  float64
#  47  pmc_195_alc                                         20715 non-null  float64
#  48  pmc_20                                              20715 non-null  float64
#  49  pmc_20_alc                                          20715 non-null  float64
#  50  pmc_205                                             20715 non-null  float64
#  51  pmc_21                                              20715 non-null  float64
#  52  pmc_21_alc                                          20715 non-null  float64
#  53  pmc_22                                              20715 non-null  float64
#  54  pmc_22_alc                                          20715 non-null  float64
#  55  restricao_hospitalar                                24873 non-null  bool
#  56  cap                                                 24873 non-null  bool
#  57  confaz_87                                           24873 non-null  bool
#  58  icms_0                                              24873 non-null  bool
#  59  analise_recursal                                    117 non-null    object
#  60  lista_de_concessao_de_credito_tributario_piscofins  24873 non-null  object
#  61  comercializacao_2022                                24873 non-null  bool
#  62  tarja                                               24873 non-null  object
#  63  destinacao_comercial_                               24873 non-null  object
# dtypes: bool(5), float64(23), object(36)
# memory usage: 11.3+ MB
# None
#                                substancia                cnpj  \
# 1  21-ACETATO DE DEXAMETASONA;CLOTRIMAZOL  18.459.628/0001-15
# 2                              ABATACEPTE  56.998.982/0001-07
# 3                              ABATACEPTE  56.998.982/0001-07
# 4                            ABEMACICLIBE  43.940.618/0001-44
# 5                            ABEMACICLIBE  43.940.618/0001-44
#
#                               laboratorio       codigo_ggrem         registro  \
# 1                              BAYER S.A.  538912020009303.0  1705600230032.0
# 2  BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA  505107701157215.0  1018003900019.0
# 3  BRISTOL-MYERS SQUIBB FARMACÊUTICA LTDA  505113100020505.0  1018003900078.0
# 4                ELI LILLY DO BRASIL LTDA  507619060021902.0  1126001990018.0
# 5                ELI LILLY DO BRASIL LTDA  507619060022102.0  1126001990034.0
#
#            ean_1       ean_2       ean_3     produto  \
# 1  7891106000956      -           -       BAYCUTEN N
# 2  7896016806469      -           -          ORENCIA
# 3  7896016808197      -           -          ORENCIA
# 4  7896382708442      -           -        VERZENIOS
# 5  7896382708466      -           -        VERZENIOS
#
#                                         apresentacao  ... pmvg_22_alc  \
# 1     10 MG/G + 0,443 MG/G CREM DERM CT BG AL X 40 G  ...       25.94
# 2   250 MG PO LIOF SOL INJ CT 1 FA + SER DESCARTÁVEL  ...     2034.37
# 3  125 MG/ML SOL INJ SC CT 4 SER PREENC VD TRANS ...  ...         NaN
# 4                     50 MG COM REV CT BL AL AL X 30  ...     2731.66
# 5                    100 MG COM REV CT BL AL AL X 30  ...     5463.29
#
#   restricao_hospitalar    cap  confaz_87  icms_0 analise_recursal  \
# 1                False  False      False   False              NaN
# 2                 True   True      False   False              NaN
# 3                False   True       True   False              NaN
# 4                False  False      False   False              NaN
# 5                False  False      False   False              NaN
#
#   lista_de_concessao_de_credito_tributario_piscofins comercializacao_2022  \
# 1                                           Negativa                 True
# 2                                           Positiva                 True
# 3                                           Positiva                 True
# 4                                           Negativa                 True
# 5                                           Negativa                 True
#
#             tarja destinacao_comercial_
# 1          - (*)                    Sim
# 2  Tarja Vermelha                   Sim
# 3          - (*)                    Sim
# 4  Tarja Vermelha                   Não
# 5  Tarja Vermelha                   Não
#
# [5 rows x 64 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24873 entries, 1 to 24873
# Data columns (total 64 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   substancia                                          24873 non-null  object
#  1   cnpj                                                24873 non-null  object
#  2   laboratorio                                         24873 non-null  object
#  3   codigo_ggrem                                        24873 non-null  object
#  4   registro                                            24873 non-null  object
#  5   ean_1                                               24873 non-null  object
#  6   ean_2                                               24873 non-null  object
#  7   ean_3                                               24873 non-null  object
#  8   produto                                             24873 non-null  object
#  9   apresentacao                                        24873 non-null  object
#  10  classe_terapeutica                                  24873 non-null  object
#  11  tipo_de_produto_status_do_produto                   24873 non-null  object
#  12  regime_de_preco                                     24873 non-null  object
#  13  pf_sem_impostos                                     24873 non-null  float64
#  14  pf_0                                                24873 non-null  float64
#  15  pf_12                                               24873 non-null  object
#  16  pf_12_alc                                           24873 non-null  object
#  17  pf_17                                               24873 non-null  object
#  18  pf_17_alc                                           24873 non-null  object
#  19  pf_175                                              24873 non-null  object
#  20  pf_175_alc                                          24873 non-null  object
#  21  pf_18                                               24873 non-null  object
#  22  pf_18_alc                                           24873 non-null  object
#  23  pf_19                                               24873 non-null  object
#  24  pf_19_alc                                           24873 non-null  object
#  25  pf_195                                              24873 non-null  object
#  26  pf_195_alc                                          24873 non-null  object
#  27  pf_20                                               24873 non-null  object
#  28  pf_20_alc                                           24873 non-null  object
#  29  pf_2052                                             24873 non-null  object
#  30  pf_21                                               24873 non-null  object
#  31  pf_21_alc                                           24873 non-null  object
#  32  pf_22                                               24873 non-null  object
#  33  pf_22_alc                                           24873 non-null  object
#  34  pmvg_sem_imposto                                    24873 non-null  float64
#  35  pmvg_0                                              24873 non-null  float64
#  36  pmvg_12                                             21483 non-null  float64
#  37  pmvg_12_alc                                         21483 non-null  float64
#  38  pmvg_17                                             21483 non-null  float64
#  39  pmvg_17_alc                                         21483 non-null  float64
#  40  pmvg_175                                            21483 non-null  float64
#  41  pmvg_175_alc                                        21483 non-null  float64
#  42  pmvg_18                                             21483 non-null  float64
#  43  pmvg_18_alc                                         21483 non-null  float64
#  44  pmvg_19                                             21483 non-null  float64
#  45  pmvg_19_alc                                         21483 non-null  float64
#  46  pmvg_195                                            21483 non-null  float64
#  47  pmvg_195_alc                                        21483 non-null  float64
#  48  pmvg_20                                             21483 non-null  float64
#  49  pmvg_20_alc                                         21483 non-null  float64
#  50  pmvg_205                                            21483 non-null  float64
#  51  pmvg_21                                             21483 non-null  float64
#  52  pmvg_21_alc                                         21483 non-null  float64
#  53  pmvg_22                                             21483 non-null  float64
#  54  pmvg_22_alc                                         21483 non-null  float64
#  55  restricao_hospitalar                                24873 non-null  object
#  56  cap                                                 24873 non-null  object
#  57  confaz_87                                           24873 non-null  object
#  58  icms_0                                              24873 non-null  object
#  59  analise_recursal                                    117 non-null    object
#  60  lista_de_concessao_de_credito_tributario_piscofins  24873 non-null  object
#  61  comercializacao_2022                                24873 non-null  object
#  62  tarja                                               24873 non-null  object
#  63  destinacao_comercial_                               24873 non-null  object
# dtypes: float64(23), object(41)
# memory usage: 12.1+ MB
# None

# %%
pmc_df.to_csv('pmc.csv')
pmvg_df.to_csv('pmvg.csv')

# %%
# Carregar o arquivo CSV
unimed_df = pd.read_csv('unimed_raw.csv')  # Ajuste o separador se necessário

# %%
# Visualizar as primeiras linhas
print(unimed_df.head())

# Informações básicas do DataFrame
print(unimed_df.info())
# Out:
#            diario  ano_caderno  num_caderno       data_publicacao  \
# 0  20191029cC.txt         2019           40  2019-10-29T00:00:00Z
# 1   20161130I.txt         2015           59  2016-11-30T00:00:00Z
# 2  20181112cI.txt         2018           48  2018-11-12T00:00:00Z
# 3   20150505C.txt         2012          156  2015-05-05T00:00:00Z
# 4   20150812I.txt         2013          224  2015-08-12T00:00:00Z
#
#                                            vara_nome  \
# 0  *** capital conselho recursal dos jecs e jecri...
# 1                                      2a vara civel
# 2                                 1a vara de familia
# 3                                     34a vara civel
# 4                                      2a vara civel
#
#                     processo  \
# 0  0013960-09.2019.8.19.0210
# 1  0022008-23.2015.8.19.0007
# 2  0002071-08.2018.8.19.0044
# 3  0272331-71.2012.8.19.0001
# 4  0001099-27.2013.8.19.0072
#
#                                           ocorrencia  \
# 0  070. recurso inominado 0013960-09.2019.8.19.02...
# 1  proc. 0022008-23.2015.8.19.0007 - dione krull ...
# 2  proc. 0002071-08.2018.8.19.0044 - paulo sergio...
# 3  proc. 0272331-71.2012.8.19.0001 - ana paula ma...
# 4  proc. 0001099-27.2013.8.19.0072 - asafe alves ...
#
#                                                   pa  \
# 0           movimentação sem polo ativo identificado
# 1  dione krull dos santos (adv(s). dr(a). thiago ...
# 2                             paulo sergio goncalves
# 3  ana paula malta saraiva andrade dos santos (ad...
# 4  asafe alves velloso do nascimento (adv(s). dr(...
#
#                                                   pp  \
# 0         movimentação sem polo passivo identificado
# 1  unimed barra mansa (adv(s). dr(a). marcus vini...
# 2  unimed norte fluminense e outro (adv(s). dr(a)...
# 3  unimed brasilia (adv(s). dr(a). antonio carlos...
# 4     abrasf - associacao brasileira de apoio social
#
#                                                  adv  ...   ano       mes  \
# 0          oab/rj-102452;oab/rj-205703;oab/rj-202870  ...  2019   outubro
# 1  oab/rj-163009;oab/rj-200801;oab/rj-110020;oab/...  ...  2015  novembro
# 2  oab/rj-060128;oab/rj-159491;oab/rj-202952;oab/...  ...  2018  novembro
# 3                        oab/rj-112253;oab/ba-013325  ...  2012      maio
# 4                        oab/rj-174270;oab/rj-053755  ...  2013    agosto
#
#                               tutela              tutela_acao  \
# 0  movimentação sem tutela apreciada  tutela não classificada
# 1  movimentação sem tutela apreciada  tutela não classificada
# 2  movimentação com tutela apreciada                   defiro
# 3  movimentação sem tutela apreciada  tutela não classificada
# 4  movimentação sem tutela apreciada  tutela não classificada
#
#                               multa                               valor  \
# 0  movimentações sem valor de multa             r$2.794,50 | r$3.000,00
# 1  movimentações sem valor de multa  movimentações sem valor encontrado
# 2  movimentações sem valor de multa  movimentações sem valor encontrado
# 3  movimentações sem valor de multa  movimentações sem valor encontrado
# 4                         r$ 500,00                           r$ 500,00
#
#                acao flag           descritor ano_referencia
# 0       nao provido    2      plano de saude           2019
# 1       nao provido  111  (art.?|artigo) 196           2016
# 2  não classificado    1      plano de saude           2018
# 3  não classificado    1      plano de saude           2015
# 4  não classificado    1      plano de saude           2015
#
# [5 rows x 25 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   diario              996 non-null    object
#  1   ano_caderno         996 non-null    int64
#  2   num_caderno         996 non-null    int64
#  3   data_publicacao     996 non-null    object
#  4   vara_nome           996 non-null    object
#  5   processo            996 non-null    object
#  6   ocorrencia          996 non-null    object
#  7   pa                  996 non-null    object
#  8   pp                  996 non-null    object
#  9   adv                 990 non-null    object
#  10  tempo_processo_mes  996 non-null    object
#  11  tempo_processo_ano  996 non-null    object
#  12  tipo                996 non-null    object
#  13  assunto_agravo      996 non-null    object
#  14  movimentacao        996 non-null    object
#  15  ano                 996 non-null    int64
#  16  mes                 996 non-null    object
#  17  tutela              996 non-null    object
#  18  tutela_acao         996 non-null    object
#  19  multa               996 non-null    object
#  20  valor               996 non-null    object
#  21  acao                996 non-null    object
#  22  flag                996 non-null    int64
#  23  descritor           996 non-null    object
#  24  ano_referencia      996 non-null    int64
# dtypes: int64(5), object(20)
# memory usage: 194.7+ KB
# None

# %%
def normalize_column(col_name):
    # Converter para minúsculas
    col_name = col_name.lower()
    
    # Remover acentos
    col_name = ''.join(
        c for c in unicodedata.normalize('NFD', col_name)
        if unicodedata.category(c) != 'Mn'
    )
    
    # Substituir espaços e caracteres especiais por underscores
    col_name = re.sub(r'\s+', '_', col_name)  # Substituir espaços por '_'
    col_name = re.sub(r'[^\w_]', '', col_name)  # Remover caracteres não alfanuméricos
    
    return col_name

# Renomear as colunas
unimed_df.rename(columns=lambda x: normalize_column(x), inplace=True)

# Verificar as novas colunas
print(unimed_df.columns)
# Out:
# Index(['diario', 'ano_caderno', 'num_caderno', 'data_publicacao', 'vara_nome',
#        'processo', 'ocorrencia', 'pa', 'pp', 'adv', 'tempo_processo_mes',
#        'tempo_processo_ano', 'tipo', 'assunto_agravo', 'movimentacao', 'ano',
#        'mes', 'tutela', 'tutela_acao', 'multa', 'valor', 'acao', 'flag',
#        'descritor', 'ano_referencia'],
#       dtype='object')

# %%
def clean_monetary_value(value):
    """
    Limpa e converte strings monetárias para float.
    Remove 'r$', pontos de milhares e substitui vírgula por ponto decimal.
    """
    if pd.isnull(value):
        return np.nan
    value = str(value)
    # Remover 'r$' e quaisquer espaços
    value = re.sub(r'r\$\s*', '', value, flags=re.IGNORECASE)
    
    # Identificar o último separador decimal (',' ou '.')
    match = re.search(r'([.,])(?=\d{2}$)', value)
    if match:
        # Substituir o separador decimal por '#'
        value = re.sub(r'([.,])(?=\d{2}$)', '#', value)
        # Remover todos os outros pontos e vírgulas
        value = re.sub(r'[.,]', '', value)
        # Substituir '#' por ponto decimal
        value = value.replace('#', '.')
    else:
        # Nenhum separador decimal identificado; remover todos os pontos e vírgulas
        value = value.replace('.', '').replace(',', '')
    
    try:
        return float(value)
    except ValueError:
        return np.nan  # Retorna NaN se não for possível converter

def clean_monetary_value_max(value):
    """
    Limpa e converte strings monetárias para float.
    Remove 'r$', pontos de milhares e substitui vírgula por ponto decimal.
    Em casos com múltiplos valores separados por '|', retorna o maior valor.
    """
    if pd.isnull(value):
        return np.nan
    value = str(value)
    # Dividir por '|'
    parts = [part.strip() for part in value.split('|')]
    cleaned_values = []
    for part in parts:
        float_val = clean_monetary_value(part)
        if not np.isnan(float_val):
            cleaned_values.append(float_val)
    if cleaned_values:
        return max(cleaned_values)
    else:
        return np.nan


def format_data_types(df):
    """
    Formata os tipos de dados das colunas do DataFrame.
    """
    # Converter colunas de data para datetime
    if 'data_publicacao' in df.columns:
        df['data_publicacao'] = pd.to_datetime(df['data_publicacao'], errors='coerce')
    
    # Converter colunas de ano para inteiro
    ano_cols = ['ano_caderno', 'ano']
    for col in ano_cols:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce').astype('Int64')
    
    # Converter colunas de número para inteiro
    num_cols = ['num_caderno', 'tempo_processo_mes', 'tempo_processo_ano']
    for col in num_cols:
        if col in df.columns:
            if col == 'tempo_processo_mes':
                # Substituir a string específica por 0
                df[col] = df[col].replace('processo com menos de 1 ano', 0)
                # Converter para numérico, forçando erros para NaN e preenchendo com 0
                df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype('Int64')
            else:
                df[col] = pd.to_numeric(df[col], errors='coerce').astype('Int64')
    
    # Converter colunas monetárias
    monetary_cols_max = ['valor']
    monetary_cols_single = ['multa']
    
    for col in monetary_cols_max:
        if col in df.columns:
            df[col] = df[col].apply(clean_monetary_value_max)
    
    for col in monetary_cols_single:
        if col in df.columns:
            df[col] = df[col].apply(clean_monetary_value)
    
    # Converter colunas booleanas
    bool_columns = ['tutela']
    for col in bool_columns:
        if col in df.columns:
            df[col] = df[col].map({'movimentação com tutela apreciada': True, 'movimentação sem tutela apreciada': False})
    
    # Converter colunas categóricas
    categorical_cols = ['tipo', 'assunto_agravo', 'movimentacao', 'mes', 'acao', 'tutela_acao']
    for col in categorical_cols:
        if col in df.columns:
            df[col] = df[col].astype('category')
    
    return df

# Aplicar a formatação no DataFrame
unimed_df = format_data_types(unimed_df)

# %%
# Visualizar as primeiras linhas
print(unimed_df.head())

# Informações básicas do DataFrame
print(unimed_df.info())
# Out:
#            diario  ano_caderno  num_caderno           data_publicacao  \
# 0  20191029cC.txt         2019           40 2019-10-29 00:00:00+00:00
# 1   20161130I.txt         2015           59 2016-11-30 00:00:00+00:00
# 2  20181112cI.txt         2018           48 2018-11-12 00:00:00+00:00
# 3   20150505C.txt         2012          156 2015-05-05 00:00:00+00:00
# 4   20150812I.txt         2013          224 2015-08-12 00:00:00+00:00
#
#                                            vara_nome  \
# 0  *** capital conselho recursal dos jecs e jecri...
# 1                                      2a vara civel
# 2                                 1a vara de familia
# 3                                     34a vara civel
# 4                                      2a vara civel
#
#                     processo  \
# 0  0013960-09.2019.8.19.0210
# 1  0022008-23.2015.8.19.0007
# 2  0002071-08.2018.8.19.0044
# 3  0272331-71.2012.8.19.0001
# 4  0001099-27.2013.8.19.0072
#
#                                           ocorrencia  \
# 0  070. recurso inominado 0013960-09.2019.8.19.02...
# 1  proc. 0022008-23.2015.8.19.0007 - dione krull ...
# 2  proc. 0002071-08.2018.8.19.0044 - paulo sergio...
# 3  proc. 0272331-71.2012.8.19.0001 - ana paula ma...
# 4  proc. 0001099-27.2013.8.19.0072 - asafe alves ...
#
#                                                   pa  \
# 0           movimentação sem polo ativo identificado
# 1  dione krull dos santos (adv(s). dr(a). thiago ...
# 2                             paulo sergio goncalves
# 3  ana paula malta saraiva andrade dos santos (ad...
# 4  asafe alves velloso do nascimento (adv(s). dr(...
#
#                                                   pp  \
# 0         movimentação sem polo passivo identificado
# 1  unimed barra mansa (adv(s). dr(a). marcus vini...
# 2  unimed norte fluminense e outro (adv(s). dr(a)...
# 3  unimed brasilia (adv(s). dr(a). antonio carlos...
# 4     abrasf - associacao brasileira de apoio social
#
#                                                  adv  ...   ano       mes  \
# 0          oab/rj-102452;oab/rj-205703;oab/rj-202870  ...  2019   outubro
# 1  oab/rj-163009;oab/rj-200801;oab/rj-110020;oab/...  ...  2015  novembro
# 2  oab/rj-060128;oab/rj-159491;oab/rj-202952;oab/...  ...  2018  novembro
# 3                        oab/rj-112253;oab/ba-013325  ...  2012      maio
# 4                        oab/rj-174270;oab/rj-053755  ...  2013    agosto
#
#   tutela              tutela_acao  multa   valor              acao  flag  \
# 0  False  tutela não classificada    NaN  3000.0       nao provido     2
# 1  False  tutela não classificada    NaN     NaN       nao provido   111
# 2   True                   defiro    NaN     NaN  não classificado     1
# 3  False  tutela não classificada    NaN     NaN  não classificado     1
# 4  False  tutela não classificada  500.0   500.0  não classificado     1
#
#             descritor  ano_referencia
# 0      plano de saude            2019
# 1  (art.?|artigo) 196            2016
# 2      plano de saude            2018
# 3      plano de saude            2015
# 4      plano de saude            2015
#
# [5 rows x 25 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   diario              996 non-null    object
#  1   ano_caderno         996 non-null    Int64
#  2   num_caderno         996 non-null    Int64
#  3   data_publicacao     996 non-null    datetime64[ns, UTC]
#  4   vara_nome           996 non-null    object
#  5   processo            996 non-null    object
#  6   ocorrencia          996 non-null    object
#  7   pa                  996 non-null    object
#  8   pp                  996 non-null    object
#  9   adv                 990 non-null    object
#  10  tempo_processo_mes  996 non-null    Int64
#  11  tempo_processo_ano  667 non-null    Int64
#  12  tipo                996 non-null    category
#  13  assunto_agravo      996 non-null    category
#  14  movimentacao        996 non-null    category
#  15  ano                 996 non-null    Int64
#  16  mes                 996 non-null    category
#  17  tutela              996 non-null    bool
#  18  tutela_acao         996 non-null    category
#  19  multa               194 non-null    float64
#  20  valor               508 non-null    float64
#  21  acao                996 non-null    category
#  22  flag                996 non-null    int64
#  23  descritor           996 non-null    object
#  24  ano_referencia      996 non-null    int64
# dtypes: Int64(5), bool(1), category(6), datetime64[ns, UTC](1), float64(2), int64(2), object(8)
# memory usage: 193.2+ KB
# None

# %%
# Salvar o DataFrame tratado em um novo CSV
unimed_df.to_csv('unimed.csv', index=False)

# %%
unimed_df.describe()
# Out:
#        ano_caderno  num_caderno  tempo_processo_mes  tempo_processo_ano  \
# count        996.0        996.0               996.0               667.0
# mean     2015.0251   118.941767            24.39759           36.431784
# std       3.198676    69.172268           33.234277           34.800237
# min         1999.0          1.0                 0.0                12.0
# 25%         2014.0         58.0                 0.0                12.0
# 50%         2015.0        121.0                12.0                24.0
# 75%         2016.0        177.0                36.0                48.0
# max         2021.0        240.0               228.0               228.0
#
#              ano          multa         valor        flag  ano_referencia
# count      996.0     194.000000  5.080000e+02  996.000000      996.000000
# mean   2015.0251   12288.344124  5.465127e+05    2.561245     2017.475904
# std     3.198676   51662.754138  1.172063e+07   10.337290        2.256965
# min       1999.0      17.980000  2.990000e+01    1.000000     2015.000000
# 25%       2014.0     500.000000  1.000000e+03    1.000000     2015.000000
# 50%       2015.0    1000.000000  4.000000e+03    1.000000     2017.000000
# 75%       2016.0    7000.000000  1.000000e+04    1.000000     2019.000000
# max       2021.0  500000.000000  2.641711e+08  196.000000     2021.000000

# %%
unimed_df['descritor'].unique()
# Out:
# array(['plano de saude', '(art.?|artigo) 196', 'cancer', 'leito uti',
#        'quimioterapia',
#        'direito ao? (assistencia farmaceutica|assistencia medica|internacao|saude|vida|tratamento|medicamento)',
#        'internacao hospitalar', 'Procarbazina', 'tratamento hormonal',
#        'Crizotinibe', 'Rituximabe', 'radioterapia', 'BIÓPSIA',
#        'Tocilizumabe', 'transplante de medula', 'cancer de mama',
#        'leucemia', 'neoplasia maligna', 'negativa de tratamento',
#        'ATENÇÃO À SAUDE', 'linfoma', 'Carboplatina',
#        'custo do tratamento', 'adenocarcinoma', 'origem da molestia',
#        'sistema unico de saude'], dtype=object)

# %%
ritu = unimed_df[unimed_df['descritor'] == 'Crizotinibe']
print(ritu.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 122 to 122
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   diario              1 non-null      object
#  1   ano_caderno         1 non-null      Int64
#  2   num_caderno         1 non-null      Int64
#  3   data_publicacao     1 non-null      datetime64[ns, UTC]
#  4   vara_nome           1 non-null      object
#  5   processo            1 non-null      object
#  6   ocorrencia          1 non-null      object
#  7   pa                  1 non-null      object
#  8   pp                  1 non-null      object
#  9   adv                 1 non-null      object
#  10  tempo_processo_mes  1 non-null      Int64
#  11  tempo_processo_ano  1 non-null      Int64
#  12  tipo                1 non-null      category
#  13  assunto_agravo      1 non-null      category
#  14  movimentacao        1 non-null      category
#  15  ano                 1 non-null      Int64
#  16  mes                 1 non-null      category
#  17  tutela              1 non-null      bool
#  18  tutela_acao         1 non-null      category
#  19  multa               1 non-null      float64
#  20  valor               1 non-null      float64
#  21  acao                1 non-null      category
#  22  flag                1 non-null      int64
#  23  descritor           1 non-null      object
#  24  ano_referencia      1 non-null      int64
# dtypes: Int64(5), bool(1), category(6), datetime64[ns, UTC](1), float64(2), int64(2), object(8)
# memory usage: 40.5+ KB
# None

# %%
import os
import re
import pandas as pd
import numpy as np
from typing import List
import unicodedata

def normalize_column(col_name: str) -> str:
    col_name = col_name.lower()
    col_name = ''.join(
        c for c in unicodedata.normalize('NFD', col_name)
        if unicodedata.category(c) != 'Mn'
    )
    col_name = re.sub(r'\s+', '_', col_name)
    col_name = re.sub(r'[^\w_]', '', col_name)
    return col_name

def format_data_types(df: pd.DataFrame) -> pd.DataFrame:
    identificacao_cols = ['cnpj', 'registro', 'codigo_ggrem']
    for col in identificacao_cols:
        if col in df.columns:
            df[col] = df[col].astype(str)
    ean_cols = ['ean_1', 'ean_2', 'ean_3']
    for col in ean_cols:
        if col in df.columns:
            df[col] = df[col].astype(str)
    numeric_columns = [col for col in df.columns if re.search(r'pmc|pmvg', col)]
    for col in numeric_columns:
        if col in df.columns:
            df[col] = df[col].replace({'-': np.nan, ',': '.'}, regex=True)
            df[col] = pd.to_numeric(df[col], errors='coerce')
    bool_columns = [
        'restricao_hospitalar', 'cap', 'confaz_87', 
        'icms_0', 'analise_recurcial', 'comercializacao_2022'
    ]
    for col in bool_columns:
        if col in df.columns:
            df[col] = df[col].map({'Sim': True, 'Não': False})
    return df

def find_header_row(df: pd.DataFrame, header_keywords: List[str]) -> int:
    header_keywords_upper = [keyword.upper() for keyword in header_keywords]
    for index, row in df.iterrows():
        row_values = row.astype(str).str.strip().str.upper()
        if any(cell in header_keywords_upper for cell in row_values):
            return index
    raise ValueError("Header row not found.")

def process_pmc_files(folder_path: str, medications: List[str]) -> pd.DataFrame:
    all_dfs = []
    header_keywords = ['SUBSTÂNCIA', 'PRINCÍPIO ATIVO']
    for filename in os.listdir(folder_path):
        if filename.lower().endswith('.xls') or filename.lower().endswith('.xlsx'):
            file_path = os.path.join(folder_path, filename)
            print(f"Processing file: {filename}")
            try:
                df_raw = pd.read_excel(file_path, header=None)
                print(f"Initial df shape: {df_raw.shape}")
                header_row = find_header_row(df_raw, header_keywords)
                print(f"Header row found at index: {header_row}")
                df = pd.read_excel(file_path, header=header_row)
                print(f"Data df shape after reading with header: {df.shape}")
                df.columns = [normalize_column(col) for col in df.columns]
                print(f"Columns after normalization: {df.columns.tolist()}")
                df = format_data_types(df)
                if 'substancia' in df.columns:
                    print(f"Unique 'substancia' values before filtering: {df['substancia'].unique()}")
                    df = df[df['substancia'].isin(medications)]
                    print(f"Data df shape after filtering: {df.shape}")
                else:
                    raise ValueError(f"'substancia' column not found in {filename}.")
                if df.empty:
                    print(f"No matching data found in {filename} after filtering.")
                    continue
                match = re.search(r'pmc_(jan|fev|mar|abr|mai|jun|jul|ago|set|out|nov|dez)_(\d{4})', filename.lower())
                if match:
                    month_str = match.group(1)
                    year = match.group(2)
                    month_map = {
                        'jan': '01', 'fev': '02', 'mar': '03', 'abr': '04',
                        'mai': '05', 'jun': '06', 'jul': '07', 'ago': '08',
                        'set': '09', 'out': '10', 'nov': '11', 'dez': '12'
                    }
                    mes = month_map.get(month_str, '01')
                else:
                    mes = 'Unknown'
                    year = 'Unknown'
                print(f"Extracted month: {mes}, year: {year}")
                df['mes'] = mes
                df['ano'] = year
                all_dfs.append(df)
                print(f"Added data from {filename} to the list.")
            except Exception as e:
                print(f"Erro ao processar o arquivo {filename}: {e}")
    if all_dfs:
        df_merged = pd.concat(all_dfs, ignore_index=True)
        print(f"Merged DataFrame shape: {df_merged.shape}")
        return df_merged
    else:
        print("Nenhum DataFrame foi criado. Verifique os arquivos e os filtros aplicados.")
        return pd.DataFrame()

# %%
# Example usage:
folder_path = 'pmcs'
medications = ['PROCARBAZINA', 'CRIZOTINIBE', 'RITUXIMABE', 'TOCILIZUMABE', 'CARBOPLATINA']
df_merged = process_pmc_files(folder_path, medications=medications)
print(df_merged.head())
# Out:
# Processing file: pmc_jul_2022.xls
# Initial df shape: (27190, 40)
# Header row found at index: 47
# Data df shape after reading with header: (27142, 40)
# Columns after normalization: ['substancia', 'cnpj', 'laboratorio', 'codigo_ggrem', 'registro', 'ean_1', 'ean_2', 'ean_3', 'produto', 'apresentacao', 'classe_terapeutica', 'tipo_de_produto_status_do_produto', 'regime_de_preco', 'pf_sem_impostos', 'pf_0', 'pf_12', 'pf_17', 'pf_17_alc', 'pf_175', 'pf_175_alc', 'pf_18', 'pf_18_alc', 'pf_20', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_17_alc', 'pmc_175', 'pmc_175_alc', 'pmc_18', 'pmc_18_alc', 'pmc_20', 'restricao_hospitalar', 'cap', 'confaz_87', 'icms_0', 'analise_recursal', 'lista_de_concessao_de_credito_tributario_piscofins', 'comercializacao_2020', 'tarja']
# Unique 'substancia' values before filtering: ['21-ACETATO DE DEXAMETASONA;CLOTRIMAZOL' 'ABATACEPTE' 'ABCIXIMABE' ...
#  'ZOLMITRIPTANA' 'ZOPICLONA' 'ZUCLOPENTIXOL']
# Data df shape after filtering: (47, 40)
# Extracted month: 07, year: 2022
# Added data from pmc_jul_2022.xls to the list.
# Processing file: pmc_jul_2023.xls
# Initial df shape: (28657, 46)
# Header row found at index: 45
# Data df shape after reading with header: (28611, 46)
# Columns after normalization: ['substancia', 'cnpj', 'laboratorio', 'codigo_ggrem', 'registro', 'ean_1', 'ean_2', 'ean_3', 'produto', 'apresentacao', 'classe_terapeutica', 'tipo_de_produto_status_do_produto', 'regime_de_preco', 'pf_sem_impostos', 'pf_0', 'pf_12', 'pf_17', 'pf_17_alc', 'pf_175', 'pf_175_alc', 'pf_18', 'pf_18_alc', 'pf_19', 'pf_20', 'pf_21', 'pf_22', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_17_alc', 'pmc_175', 'pmc_175_alc', 'pmc_18', 'pmc_18_alc', 'pmc_19', 'pmc_20', 'pmc_21', 'pmc_22', 'restricao_hospitalar', 'cap', 'confaz_87', 'icms_0', 'analise_recursal', 'lista_de_concessao_de_credito_tributario_piscofins', 'comercializacao_2022', 'tarja']
# Unique 'substancia' values before filtering: ['BUTILBROMETO DE ESCOPOLAMINA'
#  'DIPIRONA MONOIDRATADA;BUTILBROMETO DE ESCOPOLAMINA'
#  'CIPIONATO DE TESTOSTERONA' ... 'VENETOCLAX' 'RISANQUIZUMABE'
#  'UPADACITINIBE HEMI-HIDRATADO']
# Data df shape after filtering: (47, 46)
# Extracted month: 07, year: 2023
# Added data from pmc_jul_2023.xls to the list.
# Processing file: pmc_jul_2021.xls
# Initial df shape: (26009, 41)
# Header row found at index: 44
# Data df shape after reading with header: (25964, 41)
# Columns after normalization: ['substancia', 'cnpj', 'laboratorio', 'codigo_ggrem', 'unnamed_4', 'registro', 'ean_1', 'ean_2', 'ean_3', 'produto', 'apresentacao', 'classe_terapeutica', 'tipo_de_produto_status_do_produto', 'regime_de_preco', 'pf_sem_impostos', 'pf_0', 'pf_12', 'pf_17', 'pf_17_alc', 'pf_175', 'pf_175_alc', 'pf_18', 'pf_18_alc', 'pf_20', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_17_alc', 'pmc_175', 'pmc_175_alc', 'pmc_18', 'pmc_18_alc', 'pmc_20', 'restricao_hospitalar', 'cap', 'confaz_87', 'icms_0', 'analise_recursal', 'lista_de_concessao_de_credito_tributario_piscofins', 'comercializacao_2020', 'tarja']
# Unique 'substancia' values before filtering: ['VALPROATO DE SÓDIO' 'ÁCIDO VALPRÓICO'
#  'SALICILATO DE FENILA;ÁCIDO SALICÍLICO;ÓXIDO DE ZINCO;ENXOFRE;MENTOL' ...
#  'RISANQUIZUMABE' 'UPADACITINIBE HEMI-HIDRATADO' 'ISOCONAZOL;ABARELIX']
# Data df shape after filtering: (43, 41)
# Extracted month: 07, year: 2021
# Added data from pmc_jul_2021.xls to the list.
# Processing file: pmc_jul_2020.xls
# Initial df shape: (23916, 40)
# Header row found at index: 41
# Data df shape after reading with header: (23874, 40)
# Columns after normalization: ['substancia', 'cnpj', 'laboratorio', 'codigo_ggrem', 'registro', 'ean_1', 'ean_2', 'ean_3', 'produto', 'apresentacao', 'classe_terapeutica', 'tipo_de_produto_status_do_produto', 'regime_de_preco', 'pf_sem_impostos', 'pf_0', 'pf_12', 'pf_17', 'pf_17_alc', 'pf_175', 'pf_175_alc', 'pf_18', 'pf_18_alc', 'pf_20', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_17_alc', 'pmc_175', 'pmc_175_alc', 'pmc_18', 'pmc_18_alc', 'pmc_20', 'restricao_hospitalar', 'cap', 'confaz_87', 'icms_0', 'analise_recursal', 'lista_de_concessao_de_credito_tributario_piscofins', 'comercializacao_2019', 'tarja']
# Unique 'substancia' values before filtering: ['ACETATO DE CLORMADINONA;ETINILESTRADIOL' 'ATALURENO' 'COLECALCIFEROL'
#  ...
#  'IODETO DE POTÁSSIO;NICOTINAMIDA;SULFATO DE MANGANÊS;PALMITATO DE RETINOL;PANAX GINSENG C. A. MEY.;SULFATO FERROSO;RIBOFLAVINA;CLORIDRATO DE PIRIDOXINA;ÁCIDO ASCÓRBICO;CIANOCOBALAMINA;FLUORETO DE SÓDIO;SULFATO DE POTÁSSIO;RUTOSÍDEO;D-PANTENOL;FOSFATO DE CÁLCIO DIBÁSICO;NITRATO DE TIAMINA;ACETATO DE RACEALFATOCOFEROL;SULFATO DE MAGNÉSIO;BIOTINA;COLECALCIFEROL'
#  'ALPELISIBE' 'MALEATO DE TIMOLOL;LATANOPROSTA']
# Data df shape after filtering: (42, 40)
# Extracted month: 07, year: 2020
# Added data from pmc_jul_2020.xls to the list.
# Processing file: pmc_jul_2018.xls
# Initial df shape: (25935, 35)
# Header row found at index: 37
# Data df shape after reading with header: (25897, 35)
# Columns after normalization: ['principio_ativo', 'cnpj', 'laboratorio', 'codigo_ggrem', 'registro', 'ean', 'produto', 'apresentacao', 'classe_terapeutica', 'tipo_de_produto_status_do_produto', 'pf_0', 'pf_12', 'pf_17', 'pf_17_alc', 'pf_175', 'pf_175_alc', 'pf_18', 'pf_18_alc', 'pf_20', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_17_alc', 'pmc_175', 'pmc_175_alc', 'pmc_18', 'pmc_18_alc', 'pmc_20', 'restricao_hospitalar', 'cap', 'confaz_87', 'analise_recursal', 'lista_de_concessao_de_credito_tributario_piscofins', 'comercializacao_2016', 'tarja']
# Erro ao processar o arquivo pmc_jul_2018.xls: 'substancia' column not found in pmc_jul_2018.xls.
# Processing file: pmc_jul_2024.xls
# Initial df shape: (30256, 64)
# Header row found at index: 41
# Data df shape after reading with header: (30214, 64)
# Columns after normalization: ['substancia', 'cnpj', 'laboratorio', 'codigo_ggrem', 'registro', 'ean_1', 'ean_2', 'ean_3', 'produto', 'apresentacao', 'classe_terapeutica', 'tipo_de_produto_status_do_produto', 'regime_de_preco', 'pf_sem_impostos', 'pf_0', 'pf_12', 'pf_12_alc', 'pf_17', 'pf_17_alc', 'pf_175', 'pf_175_alc', 'pf_18', 'pf_18_alc', 'pf_19', 'pf_19_alc', 'pf_195', 'pf_195_alc', 'pf_20', 'pf_20_alc', 'pf_205', 'pf_21', 'pf_21_alc', 'pf_22', 'pf_22_alc', 'pmc_sem_imposto', 'pmc_0', 'pmc_12', 'pmc_12_alc', 'pmc_17', 'pmc_17_alc', 'pmc_175', 'pmc_175_alc', 'pmc_18', 'pmc_18_alc', 'pmc_19', 'pmc_19_alc', 'pmc_195', 'pmc_195_alc', 'pmc_20', 'pmc_20_alc', 'pmc_205', 'pmc_21', 'pmc_21_alc', 'pmc_22', 'pmc_22_alc', 'restricao_hospitalar', 'cap', 'confaz_87', 'icms_0', 'analise_recursal', 'lista_de_concessao_de_credito_tributario_piscofins', 'comercializacao_2022', 'tarja', 'destinacao_comercial_']
# Unique 'substancia' values before filtering: ['21-ACETATO DE DEXAMETASONA;CLOTRIMAZOL' 'ABATACEPTE' 'ABCIXIMABE' ...
#  'ÓXIDO DE ZINCO' 'ÓXIDO DE ZINCO;RETINOL;COLECALCIFEROL'
#  'ÓXIDO DE ZINCO;ÁCIDO ASCÓRBICO']
# Data df shape after filtering: (44, 64)
# Extracted month: 07, year: 2024
# Added data from pmc_jul_2024.xls to the list.
# Processing file: pmc_jul_2019.xls
# Initial df shape: (25079, 40)
# Header row found at index: 38
# Data df shape after reading with header: (25040, 40)
# Columns after normalization: ['substancia', 'cnpj', 'laboratorio', 'codigo_ggrem', 'registro', 'ean_1', 'ean_2', 'ean_3', 'produto', 'apresentacao', 'classe_terapeutica', 'tipo_de_produto_status_do_produto', 'regime_de_preco', 'pf_sem_impostos', 'pf_0', 'pf_12', 'pf_17', 'pf_17_alc', 'pf_175', 'pf_175_alc', 'pf_18', 'pf_18_alc', 'pf_20', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_17_alc', 'pmc_175', 'pmc_175_alc', 'pmc_18', 'pmc_18_alc', 'pmc_20', 'restricao_hospitalar', 'cap', 'confaz_87', 'icms_0', 'analise_recursal', 'lista_de_concessao_de_credito_tributario_piscofins', 'comercializacao_2018', 'tarja']
# Unique 'substancia' values before filtering: ['CEFALOTINA SÓDICA' 'CEFAZOLINA SÓDICA' 'CEFOTAXIMA SÓDICA' ...
#  'ALFAVESTRONIDASE' 'LUMACAFTOR;IVACAFTOR' 'IVACAFTOR']
# Data df shape after filtering: (45, 40)
# Extracted month: 07, year: 2019
# Added data from pmc_jul_2019.xls to the list.
# Processing file: pmc_jan_2016.xls
# Initial df shape: (24242, 28)
# Header row found at index: 3
# Data df shape after reading with header: (24238, 28)
# Columns after normalization: ['principio_ativo', 'cnpj', 'laboratorio', 'codigo_ggrem', 'registro', 'ean', 'produto', 'apresentacao', 'classe_terapeutica', 'pf_0', 'pf_12', 'pf_17', 'pf_18', 'pf_19', 'pf_17_zona_franca_de_manaus', 'pf_18_zona_franca_de_manaus', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_18', 'pmc_19', 'pmc_17_zona_franca_de_manaus', 'pmc_18_zona_franca_de_manaus', 'restricao_hospitalar', 'cap', 'confaz_87', 'analise_recursal', 'ultima_alteracao']
# Erro ao processar o arquivo pmc_jan_2016.xls: 'substancia' column not found in pmc_jan_2016.xls.
# Processing file: pmc_jan_2017.xls
# Initial df shape: (24949, 31)
# Header row found at index: 9
# Data df shape after reading with header: (24939, 31)
# Columns after normalization: ['principio_ativo', 'cnpj', 'laboratorio', 'codigo_ggrem', 'registro', 'ean', 'produto', 'apresentacao', 'classe_terapeutica', 'pf_0', 'pf_12', 'pf_17', 'pf_17_alc', 'pf_175', 'pf_175_alc', 'pf_18', 'pf_18_alc', 'pf_20', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_17_alc', 'pmc_175', 'pmc_175_alc', 'pmc_18', 'pmc_18_alc', 'pmc_20', 'restricao_hospitalar', 'cap', 'confaz_87', 'analise_recursal']
# Erro ao processar o arquivo pmc_jan_2017.xls: 'substancia' column not found in pmc_jan_2017.xls.
# Processing file: pmc_jul_2017.xls
# Initial df shape: (25922, 34)
# Header row found at index: 34
# Data df shape after reading with header: (25887, 34)
# Columns after normalization: ['principio_ativo', 'cnpj', 'laboratorio', 'codigo_ggrem', 'registro', 'ean', 'produto', 'apresentacao', 'classe_terapeutica', 'tipo_de_produto_status_do_produto', 'pf_0', 'pf_12', 'pf_17', 'pf_17_alc', 'pf_175', 'pf_175_alc', 'pf_18', 'pf_18_alc', 'pf_20', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_17_alc', 'pmc_175', 'pmc_175_alc', 'pmc_18', 'pmc_18_alc', 'pmc_20', 'restricao_hospitalar', 'cap', 'confaz_87', 'analise_recursal', 'lista_de_concessao_de_credito_tributario_piscofins', 'comercializacao_2016']
# Erro ao processar o arquivo pmc_jul_2017.xls: 'substancia' column not found in pmc_jul_2017.xls.
# Processing file: pmc_jul_2016.xls
# Initial df shape: (25321, 32)
# Header row found at index: 9
# Data df shape after reading with header: (25311, 32)
# Columns after normalization: ['principio_ativo', 'cnpj', 'laboratorio', 'codigo_ggrem', 'registro', 'ean', 'produto', 'apresentacao', 'classe_terapeutica', 'pf_0', 'pf_12', 'pf_17', 'pf_17_alc', 'pf_175', 'pf_175_alc', 'pf_18', 'pf_18_alc', 'pf_20', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_17_alc', 'pmc_175', 'pmc_175_alc', 'pmc_18', 'pmc_18_alc', 'pmc_20', 'restricao_hospitalar', 'cap', 'confaz_87', 'analise_recursal', 'ultima_alteracao']
# Erro ao processar o arquivo pmc_jul_2016.xls: 'substancia' column not found in pmc_jul_2016.xls.
# Processing file: pmc_jul_2014.xls
# Initial df shape: (25800, 23)
# Header row found at index: 3
# Data df shape after reading with header: (25796, 23)
# Columns after normalization: ['principio_ativo', 'cnpj', 'laboratorio', 'codigo_ggrem', 'ean', 'produto', 'apresentacao', 'pf_0', 'pf_12', 'pf_17', 'pf_18', 'pf_19', 'pf_17_zona_franca_de_manaus', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_18', 'pmc_19', 'pmc_17_zona_franca_de_manaus', 'restricao_hospitalar', 'cap', 'confaz_87', 'analise_recursal']
# Erro ao processar o arquivo pmc_jul_2014.xls: 'substancia' column not found in pmc_jul_2014.xls.
# Processing file: pmc_jan_2019.xls
# Initial df shape: (24168, 38)
# Header row found at index: 37
# Data df shape after reading with header: (24130, 38)
# Columns after normalization: ['principio_ativo', 'cnpj', 'laboratorio', 'codigo_ggrem', 'registro', 'ean_1', 'ean_2', 'ean_3', 'produto', 'apresentacao', 'classe_terapeutica', 'tipo_de_produto_status_do_produto', 'pf_sem_impostos', 'pf_0', 'pf_12', 'pf_17', 'pf_17_alc', 'pf_175', 'pf_175_alc', 'pf_18', 'pf_18_alc', 'pf_20', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_17_alc', 'pmc_175', 'pmc_175_alc', 'pmc_18', 'pmc_18_alc', 'pmc_20', 'restricao_hospitalar', 'cap', 'confaz_87', 'analise_recursal', 'lista_de_concessao_de_credito_tributario_piscofins', 'comercializacao_2017', 'tarja']
# Erro ao processar o arquivo pmc_jan_2019.xls: 'substancia' column not found in pmc_jan_2019.xls.
# Processing file: pmc_jan_2018.xls
# Initial df shape: (25150, 35)
# Header row found at index: 34
# Data df shape after reading with header: (25115, 35)
# Columns after normalization: ['principio_ativo', 'cnpj', 'laboratorio', 'codigo_ggrem', 'registro', 'ean', 'produto', 'apresentacao', 'classe_terapeutica', 'tipo_de_produto_status_do_produto', 'pf_0', 'pf_12', 'pf_17', 'pf_17_alc', 'pf_175', 'pf_175_alc', 'pf_18', 'pf_18_alc', 'pf_20', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_17_alc', 'pmc_175', 'pmc_175_alc', 'pmc_18', 'pmc_18_alc', 'pmc_20', 'restricao_hospitalar', 'cap', 'confaz_87', 'analise_recursal', 'lista_de_concessao_de_credito_tributario_piscofins', 'comercializacao_2016', 'tarja']
# Erro ao processar o arquivo pmc_jan_2018.xls: 'substancia' column not found in pmc_jan_2018.xls.
# Processing file: pmc_jan_2024.xls
# Initial df shape: (29360, 63)
# Header row found at index: 41
# Data df shape after reading with header: (29318, 63)
# Columns after normalization: ['substancia', 'cnpj', 'laboratorio', 'codigo_ggrem', 'registro', 'ean_1', 'ean_2', 'ean_3', 'produto', 'apresentacao', 'classe_terapeutica', 'tipo_de_produto_status_do_produto', 'regime_de_preco', 'pf_sem_impostos', 'pf_0', 'pf_12', 'pf_12_alc', 'pf_17', 'pf_17_alc', 'pf_175', 'pf_175_alc', 'pf_18', 'pf_18_alc', 'pf_19', 'pf_19_alc', 'pf_195', 'pf_195_alc', 'pf_20', 'pf_20_alc', 'pf_205', 'pf_21', 'pf_21_alc', 'pf_22', 'pf_22_alc', 'pmc_sem_imposto', 'pmc_0', 'pmc_12', 'pmc_12_alc', 'pmc_17', 'pmc_17_alc', 'pmc_175', 'pmc_175_alc', 'pmc_18', 'pmc_18_alc', 'pmc_19', 'pmc_19_alc', 'pmc_195', 'pmc_195_alc', 'pmc_20', 'pmc_20_alc', 'pmc_205', 'pmc_21', 'pmc_21_alc', 'pmc_22', 'pmc_22_alc', 'restricao_hospitalar', 'cap', 'confaz_87', 'icms_0', 'analise_recursal', 'lista_de_concessao_de_credito_tributario_piscofins', 'comercializacao_2022', 'tarja']
# Unique 'substancia' values before filtering: ['21-ACETATO DE DEXAMETASONA;CLOTRIMAZOL' 'ABATACEPTE' 'ABCIXIMABE' ...
#  'ÓXIDO DE ZINCO' 'ÓXIDO DE ZINCO;RETINOL;COLECALCIFEROL'
#  'ÓXIDO DE ZINCO;ÁCIDO ASCÓRBICO']
# Data df shape after filtering: (44, 63)
# Extracted month: 01, year: 2024
# Added data from pmc_jan_2024.xls to the list.
# Processing file: pmc_jul_2015.xls
# Initial df shape: (27403, 24)
# Header row found at index: 3
# Data df shape after reading with header: (27399, 24)
# Columns after normalization: ['principio_ativo', 'cnpj', 'laboratorio', 'codigo_ggrem', 'ean', 'produto', 'apresentacao', 'classe_terapeutica', 'pf_0', 'pf_12', 'pf_17', 'pf_18', 'pf_19', 'pf_17_zona_franca_de_manaus', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_18', 'pmc_19', 'pmc_17_zona_franca_de_manaus', 'restricao_hospitalar', 'cap', 'confaz_87', 'analise_recursal']
# Erro ao processar o arquivo pmc_jul_2015.xls: 'substancia' column not found in pmc_jul_2015.xls.
# Processing file: pmc_jan_2020.xls
# Initial df shape: (26084, 40)
# Header row found at index: 39
# Data df shape after reading with header: (26044, 40)
# Columns after normalization: ['substancia', 'cnpj', 'laboratorio', 'codigo_ggrem', 'registro', 'ean_1', 'ean_2', 'ean_3', 'produto', 'apresentacao', 'classe_terapeutica', 'tipo_de_produto_status_do_produto', 'regime_de_preco', 'pf_sem_impostos', 'pf_0', 'pf_12', 'pf_17', 'pf_17_alc', 'pf_175', 'pf_175_alc', 'pf_18', 'pf_18_alc', 'pf_20', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_17_alc', 'pmc_175', 'pmc_175_alc', 'pmc_18', 'pmc_18_alc', 'pmc_20', 'restricao_hospitalar', 'cap', 'confaz_87', 'icms_0', 'analise_recursal', 'lista_de_concessao_de_credito_tributario_piscofins', 'comercializacao_2018', 'tarja']
# Unique 'substancia' values before filtering: ['ABATACEPTE' 'ABCIXIMABE' 'ABEMACICLIBE' ... 'ZOLMITRIPTANA' 'ZOPICLONA'
#  'ZUCLOPENTIXOL']
# Data df shape after filtering: (47, 40)
# Extracted month: 01, year: 2020
# Added data from pmc_jan_2020.xls to the list.
# Processing file: pmc_jan_2021.xls
# Initial df shape: (25948, 40)
# Header row found at index: 41
# Data df shape after reading with header: (25906, 40)
# Columns after normalization: ['substancia', 'cnpj', 'laboratorio', 'codigo_ggrem', 'registro', 'ean_1', 'ean_2', 'ean_3', 'produto', 'apresentacao', 'classe_terapeutica', 'tipo_de_produto_status_do_produto', 'regime_de_preco', 'pf_sem_impostos', 'pf_0', 'pf_12', 'pf_17', 'pf_17_alc', 'pf_175', 'pf_175_alc', 'pf_18', 'pf_18_alc', 'pf_20', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_17_alc', 'pmc_175', 'pmc_175_alc', 'pmc_18', 'pmc_18_alc', 'pmc_20', 'restricao_hospitalar', 'cap', 'confaz_87', 'icms_0', 'analise_recursal', 'lista_de_concessao_de_credito_tributario_piscofins', 'comercializacao_2019', 'tarja']
# Unique 'substancia' values before filtering: ['21-ACETATO DE DEXAMETASONA;CLOTRIMAZOL' 'ABATACEPTE' 'ABCIXIMABE' ...
#  'ZOLMITRIPTANA' 'ZOPICLONA' 'ZUCLOPENTIXOL']
# Data df shape after filtering: (43, 40)
# Extracted month: 01, year: 2021
# Added data from pmc_jan_2021.xls to the list.
# Processing file: pmc_jan_2023.xls
# Initial df shape: (28144, 46)
# Header row found at index: 46
# Data df shape after reading with header: (28097, 46)
# Columns after normalization: ['substancia', 'cnpj', 'laboratorio', 'codigo_ggrem', 'registro', 'ean_1', 'ean_2', 'ean_3', 'produto', 'apresentacao', 'classe_terapeutica', 'tipo_de_produto_status_do_produto', 'regime_de_preco', 'pf_sem_impostos', 'pf_0', 'pf_12', 'pf_17', 'pf_17_alc', 'pf_175', 'pf_175_alc', 'pf_18', 'pf_18_alc', 'pf_19', 'pf_20', 'pf_21', 'pf_22', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_17_alc', 'pmc_175', 'pmc_175_alc', 'pmc_18', 'pmc_18_alc', 'pmc_19', 'pmc_20', 'pmc_21', 'pmc_22', 'restricao_hospitalar', 'cap', 'confaz_87', 'icms_0', 'analise_recursal', 'lista_de_concessao_de_credito_tributario_piscofins', 'comercializacao_2022', 'tarja']
# Unique 'substancia' values before filtering: ['VALPROATO DE SÓDIO'
#  'SALICILATO DE FENILA;ÁCIDO SALICÍLICO;ÓXIDO DE ZINCO;ENXOFRE;MENTOL'
#  'DIENOGESTE;VALERATO DE ESTRADIOL' ... 'VENETOCLAX' 'RISANQUIZUMABE'
#  'UPADACITINIBE HEMI-HIDRATADO']
# Data df shape after filtering: (47, 46)
# Extracted month: 01, year: 2023
# Added data from pmc_jan_2023.xls to the list.
# Processing file: pmc_jan_2022.xls
# Initial df shape: (26689, 40)
# Header row found at index: 48
# Data df shape after reading with header: (26640, 40)
# Columns after normalization: ['substancia', 'cnpj', 'laboratorio', 'codigo_ggrem', 'registro', 'ean_1', 'ean_2', 'ean_3', 'produto', 'apresentacao', 'classe_terapeutica', 'tipo_de_produto_status_do_produto', 'regime_de_preco', 'pf_sem_impostos', 'pf_0', 'pf_12', 'pf_17', 'pf_17_alc', 'pf_175', 'pf_175_alc', 'pf_18', 'pf_18_alc', 'pf_20', 'pmc_0', 'pmc_12', 'pmc_17', 'pmc_17_alc', 'pmc_175', 'pmc_175_alc', 'pmc_18', 'pmc_18_alc', 'pmc_20', 'restricao_hospitalar', 'cap', 'confaz_87', 'icms_0', 'analise_recursal', 'lista_de_concessao_de_credito_tributario_piscofins', 'comercializacao_2020', 'tarja']
# Unique 'substancia' values before filtering: ['SALICILATO DE FENILA;ÁCIDO SALICÍLICO;ÓXIDO DE ZINCO;ENXOFRE;MENTOL'
#  'DIENOGESTE;VALERATO DE ESTRADIOL'
#  'HIDROCLOROTIAZIDA;MALEATO DE ENALAPRIL' ... 'VENETOCLAX'
#  'RISANQUIZUMABE' 'UPADACITINIBE HEMI-HIDRATADO']
# Data df shape after filtering: (45, 40)
# Extracted month: 01, year: 2022
# Added data from pmc_jan_2022.xls to the list.
# Merged DataFrame shape: (494, 70)
#      substancia                cnpj                         laboratorio  \
# 0  CARBOPLATINA  58.430.828/0001-60              BLAU FARMACÊUTICA S.A.
# 1  CARBOPLATINA  58.430.828/0001-60              BLAU FARMACÊUTICA S.A.
# 2  CARBOPLATINA  58.430.828/0001-60              BLAU FARMACÊUTICA S.A.
# 3  CARBOPLATINA  58.430.828/0001-60              BLAU FARMACÊUTICA S.A.
# 4  CARBOPLATINA  58.635.830/0001-75  FARMARIN INDUSTRIA E COMERCIO LTDA
#
#       codigo_ggrem       registro          ean_1       ean_2       ean_3  \
# 0  504401302150416  1163700140026  7896014665303      -           -
# 1  504401303157414  1163700140042  7896014665327      -           -
# 2  504401304153412  1163700140034  7896014665310      -           -
# 3  504420030065907  1163700140050  7896014665129      -           -
# 4  508618090007917  1168800260040  7898179364930      -           -
#
#      produto                                  apresentacao  ... pmc_12_alc  \
# 0  B -PLATIN     10 MG / ML    SOL INJ CT FA VD AMB X 5 ML  ...        NaN
# 1  B -PLATIN      10 MG / ML SOL INJ CT  FA VD AMB X 45 ML  ...        NaN
# 2  B -PLATIN       10 MG / ML SOL INJ CT FA VD AMB X 15 ML  ...        NaN
# 3  B -PLATIN           150 MG PO LIOF SOL INJ CT FA VD AMB  ...        NaN
# 4    EVOCARB  10 MG/ML PO LIOF INJ CT 10 FA VD AMB X 15 ML  ...        NaN
#
#   pmc_19_alc pmc_195 pmc_195_alc pmc_20_alc pmc_205 pmc_21_alc pmc_22_alc  \
# 0        NaN     NaN         NaN        NaN     NaN        NaN        NaN
# 1        NaN     NaN         NaN        NaN     NaN        NaN        NaN
# 2        NaN     NaN         NaN        NaN     NaN        NaN        NaN
# 3        NaN     NaN         NaN        NaN     NaN        NaN        NaN
# 4        NaN     NaN         NaN        NaN     NaN        NaN        NaN
#
#   destinacao_comercial_ comercializacao_2018
# 0                   NaN                  NaN
# 1                   NaN                  NaN
# 2                   NaN                  NaN
# 3                   NaN                  NaN
# 4                   NaN                  NaN
#
# [5 rows x 70 columns]

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 70 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   substancia                                          494 non-null    object
#  1   cnpj                                                494 non-null    object
#  2   laboratorio                                         494 non-null    object
#  3   codigo_ggrem                                        494 non-null    object
#  4   registro                                            494 non-null    object
#  5   ean_1                                               494 non-null    object
#  6   ean_2                                               494 non-null    object
#  7   ean_3                                               494 non-null    object
#  8   produto                                             494 non-null    object
#  9   apresentacao                                        494 non-null    object
#  10  classe_terapeutica                                  494 non-null    object
#  11  tipo_de_produto_status_do_produto                   494 non-null    object
#  12  regime_de_preco                                     494 non-null    object
#  13  pf_sem_impostos                                     494 non-null    object
#  14  pf_0                                                494 non-null    object
#  15  pf_12                                               374 non-null    object
#  16  pf_17                                               374 non-null    object
#  17  pf_17_alc                                           374 non-null    object
#  18  pf_175                                              374 non-null    object
#  19  pf_175_alc                                          374 non-null    object
#  20  pf_18                                               374 non-null    object
#  21  pf_18_alc                                           374 non-null    object
#  22  pf_20                                               374 non-null    object
#  23  pmc_0                                               57 non-null     float64
#  24  pmc_12                                              53 non-null     float64
#  25  pmc_17                                              53 non-null     float64
#  26  pmc_17_alc                                          53 non-null     float64
#  27  pmc_175                                             53 non-null     float64
#  28  pmc_175_alc                                         53 non-null     float64
#  29  pmc_18                                              53 non-null     float64
#  30  pmc_18_alc                                          53 non-null     float64
#  31  pmc_20                                              53 non-null     float64
#  32  restricao_hospitalar                                494 non-null    object
#  33  cap                                                 494 non-null    object
#  34  confaz_87                                           494 non-null    object
#  35  icms_0                                              494 non-null    object
#  36  analise_recursal                                    5 non-null      object
#  37  lista_de_concessao_de_credito_tributario_piscofins  494 non-null    object
#  38  comercializacao_2020                                135 non-null    object
#  39  tarja                                               494 non-null    object
#  40  mes                                                 494 non-null    object
#  41  ano                                                 494 non-null    object
#  42  pf_19                                               134 non-null    object
#  43  pf_21                                               134 non-null    object
#  44  pf_22                                               134 non-null    object
#  45  pmc_19                                              20 non-null     float64
#  46  pmc_21                                              20 non-null     float64
#  47  pmc_22                                              20 non-null     float64
#  48  comercializacao_2022                                182 non-null    object
#  49  unnamed_4                                           43 non-null     float64
#  50  comercializacao_2019                                85 non-null     object
#  51  pf_12_alc                                           72 non-null     object
#  52  pf_19_alc                                           72 non-null     object
#  53  pf_195                                              72 non-null     object
#  54  pf_195_alc                                          72 non-null     object
#  55  pf_20_alc                                           72 non-null     object
#  56  pf_205                                              72 non-null     object
#  57  pf_21_alc                                           72 non-null     object
#  58  pf_22_alc                                           72 non-null     object
#  59  pmc_sem_imposto                                     10 non-null     float64
#  60  pmc_12_alc                                          10 non-null     float64
#  61  pmc_19_alc                                          10 non-null     float64
#  62  pmc_195                                             10 non-null     float64
#  63  pmc_195_alc                                         10 non-null     float64
#  64  pmc_20_alc                                          10 non-null     float64
#  65  pmc_205                                             10 non-null     float64
#  66  pmc_21_alc                                          10 non-null     float64
#  67  pmc_22_alc                                          10 non-null     float64
#  68  destinacao_comercial_                               44 non-null     object
#  69  comercializacao_2018                                92 non-null     object
# dtypes: float64(22), object(48)
# memory usage: 270.3+ KB

# %%
df_merged.describe()
# Out:
#               pmc_0        pmc_12        pmc_17    pmc_17_alc       pmc_175  \
# count     57.000000     53.000000     53.000000     53.000000     53.000000
# mean   29338.973158  35723.668302  38113.854717  34494.217925  38370.675094
# std    11728.011491  11804.063394  12609.174198  11180.770194  12695.787963
# min     3783.260000   6268.110000   6645.710000   6645.710000   6685.980000
# 25%    27726.340000  31904.550000  34044.090000  30737.160000  34274.030000
# 50%    33193.540000  38195.620000  40757.060000  36798.030000  41032.290000
# 75%    36232.280000  42106.600000  44930.300000  40565.920000  45233.750000
# max    44777.790000  51525.560000  54980.910000  49640.230000  55352.240000
#
#         pmc_175_alc        pmc_18    pmc_18_alc        pmc_20        pmc_19  \
# count     53.000000     53.000000     53.000000     53.000000     20.000000
# mean   34703.287925  38630.944528  34914.890189  39708.790566  40637.331000
# std    11248.535997  12783.585952  11317.125202  13147.417466  17487.838995
# min     6685.980000   6726.750000   6726.750000   6894.930000   7551.390000
# 25%    30923.460000  34507.040000  31112.010000  35472.100000  41426.530000
# 50%    37021.070000  41311.280000  37246.800000  42466.640000  44730.705000
# 75%    40811.780000  45541.280000  41060.640000  46814.940000  54064.150000
# max    49941.110000  55728.550000  50245.620000  57287.130000  56497.030000
#
#        ...  unnamed_4  pmc_sem_imposto    pmc_12_alc    pmc_19_alc  \
# count  ...       43.0         10.00000     10.000000     10.000000
# mean   ...        0.0      30494.86000  34653.247000  37647.960000
# std    ...        0.0      13125.51473  14915.354192  16204.325156
# min    ...        0.0       6459.15000   7339.950000   7974.270000
# 25%    ...        0.0      31902.80000  36253.180000  39386.150000
# 50%    ...        0.0      33338.43000  37884.570000  41158.540000
# 75%    ...        0.0      39427.18000  44803.610000  48675.510000
# max    ...        0.0      41201.41000  46819.780000  50865.910000
#
#             pmc_195   pmc_195_alc    pmc_20_alc       pmc_205    pmc_21_alc  \
# count     10.000000     10.000000     10.000000     10.000000     10.000000
# mean   41923.140000  37226.962000  38118.568000  42511.107000  38601.100000
# std    18493.526785  16016.148499  16406.888512  18758.985934  16614.575537
# min     8023.790000   8023.790000   8073.940000   8124.720000   8176.150000
# 25%    44050.150000  38166.370000  39878.500000  44670.540000  40383.310000
# 50%    46032.410000  41414.200000  41673.030000  46680.720000  42200.560000
# 75%    54439.520000  47168.040000  49283.960000  55206.230000  49907.830000
# max    56889.300000  51181.880000  51501.750000  57690.520000  52153.690000
#
#          pmc_22_alc
# count     10.000000
# mean   39095.962000
# std    16827.576628
# min     8280.960000
# 25%    40901.020000
# 50%    42741.560000
# 75%    50547.650000
# max    52822.300000
#
# [8 rows x 22 columns]

# %%
df_merged.to_csv('pmc_2015_2024.csv')

# %%
df_merged['ano'].unique()
# Out:
# array(['2022', '2023', '2021', '2020', '2024', '2019'], dtype=object)

# %%
df_merged['mes'].unique()
# Out:
# array(['07', '01'], dtype=object)

# %%
unimed = pd.read_csv('unimed.csv')
new_base = pd.read_csv('tjrj_20.csv')

print(unimed.head(5))

print(new_base.head(5))
# Out:
#            diario  ano_caderno  num_caderno            data_publicacao  \
# 0  20191029cC.txt         2019           40  2019-10-29 00:00:00+00:00
# 1   20161130I.txt         2015           59  2016-11-30 00:00:00+00:00
# 2  20181112cI.txt         2018           48  2018-11-12 00:00:00+00:00
# 3   20150505C.txt         2012          156  2015-05-05 00:00:00+00:00
# 4   20150812I.txt         2013          224  2015-08-12 00:00:00+00:00
#
#                                            vara_nome  \
# 0  *** capital conselho recursal dos jecs e jecri...
# 1                                      2a vara civel
# 2                                 1a vara de familia
# 3                                     34a vara civel
# 4                                      2a vara civel
#
#                     processo  \
# 0  0013960-09.2019.8.19.0210
# 1  0022008-23.2015.8.19.0007
# 2  0002071-08.2018.8.19.0044
# 3  0272331-71.2012.8.19.0001
# 4  0001099-27.2013.8.19.0072
#
#                                           ocorrencia  \
# 0  070. recurso inominado 0013960-09.2019.8.19.02...
# 1  proc. 0022008-23.2015.8.19.0007 - dione krull ...
# 2  proc. 0002071-08.2018.8.19.0044 - paulo sergio...
# 3  proc. 0272331-71.2012.8.19.0001 - ana paula ma...
# 4  proc. 0001099-27.2013.8.19.0072 - asafe alves ...
#
#                                                   pa  \
# 0           movimentação sem polo ativo identificado
# 1  dione krull dos santos (adv(s). dr(a). thiago ...
# 2                             paulo sergio goncalves
# 3  ana paula malta saraiva andrade dos santos (ad...
# 4  asafe alves velloso do nascimento (adv(s). dr(...
#
#                                                   pp  \
# 0         movimentação sem polo passivo identificado
# 1  unimed barra mansa (adv(s). dr(a). marcus vini...
# 2  unimed norte fluminense e outro (adv(s). dr(a)...
# 3  unimed brasilia (adv(s). dr(a). antonio carlos...
# 4     abrasf - associacao brasileira de apoio social
#
#                                                  adv  ...   ano       mes  \
# 0          oab/rj-102452;oab/rj-205703;oab/rj-202870  ...  2019   outubro
# 1  oab/rj-163009;oab/rj-200801;oab/rj-110020;oab/...  ...  2015  novembro
# 2  oab/rj-060128;oab/rj-159491;oab/rj-202952;oab/...  ...  2018  novembro
# 3                        oab/rj-112253;oab/ba-013325  ...  2012      maio
# 4                        oab/rj-174270;oab/rj-053755  ...  2013    agosto
#
#   tutela              tutela_acao  multa   valor              acao  flag  \
# 0  False  tutela não classificada    NaN  3000.0       nao provido     2
# 1  False  tutela não classificada    NaN     NaN       nao provido   111
# 2   True                   defiro    NaN     NaN  não classificado     1
# 3  False  tutela não classificada    NaN     NaN  não classificado     1
# 4  False  tutela não classificada  500.0   500.0  não classificado     1
#
#             descritor  ano_referencia
# 0      plano de saude            2019
# 1  (art.?|artigo) 196            2016
# 2      plano de saude            2018
# 3      plano de saude            2015
# 4      plano de saude            2015
#
# [5 rows x 25 columns]
#            diario  num_caderno  ano_caderno data_publicacao  ano_processo  \
# 0  20201228cC.txt           77         2020      12/28/2020        2020.0
# 1  20201228cC.txt           77         2020      12/28/2020        2019.0
# 2  20200724cC.txt          212         2020       7/24/2020        2020.0
# 3  20200311cC.txt          123         2020       3/11/2020        2017.0
# 4  20200313cC.txt          125         2020       3/13/2020        2020.0
#
#         mes     descritor                   processo  \
# 0  dezembro   Azacitidina  0001332-65.2020.8.19.9000
# 1  dezembro  Bevacizumabe  0072336-30.2019.8.19.0002
# 2     julho    Rituximabe  0137111-23.2020.8.19.0001
# 3     março  Lenalidomida  0038437-70.2017.8.19.0209
# 4     março      Letrozol  0051967-81.2020.8.19.0001
#
#                                           ocorrencia  \
# 0  012. agravo de instrumento 0001332-65.2020.8.1...
# 1  054. recurso inominado 0072336-30.2019.8.19.00...
# 2  proc. 0137111-23.2020.8.19.0001 - diego aguiar...
# 3  074. recurso inominado 0038437-70.2017.8.19.02...
# 4  proc. 0051967-81.2020.8.19.0001 - andreza cava...
#
#                                         movimentacao  ...  \
# 0   oncologico origem niteroi cartorio unico jui ...  ...
# 1   medicamentos e outros insumos de saude - juiz...  ...
# 2   ..., no prazo de 10 dias, o tratamento com ri...  ...
# 3   indenizacao por dano moral - outras / indeniz...  ...
# 4   ...camentos ibrance 125 mg e letrozol 2,5mg c...  ...
#
#                                               partes  \
# 0  012. agravo de instrumento 0001332-65.2020.8.1...
# 1  054. recurso inominado 0072336-30.2019.8.19.00...
# 2  proc. 0137111-23.2020.8.19.0001 - diego aguiar...
# 3  074. recurso inominado 0038437-70.2017.8.19.02...
# 4  proc. 0051967-81.2020.8.19.0001 - andreza cava...
#
#                                          polos_geral  \
# 0  012. agravo de instrumento 0001332-65.2020.8.1...
# 1  054. recurso inominado 0072336-30.2019.8.19.00...
# 2  proc. 0137111-23.2020.8.19.0001 - diego aguiar...
# 3  074. recurso inominado 0038437-70.2017.8.19.02...
# 4  proc. 0051967-81.2020.8.19.0001 - andreza cava...
#
#                                              assunto  \
# 0  oncologico origemniteroi cartorio unico jui es...
# 1  medicamentos e outros insumos de saude - juiza...
# 2  ..., no prazo de 10 dias, o tratamento com rit...
# 3  indenizacao por dano moral - outras / indeniza...
# 4  ...camentos ibrance 125 mg e letrozol 2,5mg co...
#
#                                       assunto_agravo  \
# 0                                 oncologico origem:
# 1   medicamentos e outros insumos de saude - juiz...
# 2              movimentação sem assunto categorizado
# 3   indenizacao por dano moral - outras / indeniz...
# 4              movimentação sem assunto categorizado
#
#                             multas                      valor  \
# 0     movimentacao sem valor(0)(0)  movimentacao sem valor(0)
# 1     movimentacao sem valor(0)(0)  movimentacao sem valor(0)
# 2  c(" r$ 500,00", "r$ 80.000,00")  movimentacao sem valor(0)
# 3     movimentacao sem valor(0)(0)  movimentacao sem valor(0)
# 4                         r$500,00                     500,00
#
#                                               tutela  \
# 0                                         antecipada
# 1  mente significativo com baixa acuidade visual ...
# 2                  movimentação sem tutela apreciada
# 3  mente o principio da oralidade, frisando-se, o...
# 4                  movimentação sem tutela apreciada
#
#                                                  oab tempo_processo  \
# 0  oab/rj-155684 ab/tj-000009  ab/rj-202905 ab/rj...            0.0
# 1                       oab/tj-000007  ab/tj-000002             1.0
# 2  oab/rj-095701, oab/rj-211560, oab/tj-000002, o...            0.0
# 3            oab/rj-114322 ab/rj-080687 ab/rj-118911            3.0
# 4                                      oab/rj-181153            0.0
#
#   tempo_processo_mes
# 0                0.0
# 1               12.0
# 2                0.0
# 3               36.0
# 4                0.0
#
# [5 rows x 22 columns]

# %%
import pandas as pd
import numpy as np
import re

# 1. Carregar os DataFrames
unimed = pd.read_csv('unimed.csv')
new_base = pd.read_csv('tjrj_20.csv')

print("DataFrame 'unimed':")
print(unimed.head())

print("\nDataFrame 'new_base':")
print(new_base.head())

# 2. Alinhar e Renomear as Colunas
print("\nColunas do DataFrame 'unimed':")
print(unimed.columns.tolist())

print("\nColunas do DataFrame 'new_base' antes de renomear:")
print(new_base.columns.tolist())

# Renomear colunas no new_base para corresponder ao unimed
new_base.rename(columns={
    'ano_processo': 'ano_referencia',
    'multas': 'multa',
    'assunto': 'assunto_agravo',
    'oab': 'adv'
    # Não renomear 'tempo_processo' para evitar duplicatas
}, inplace=True)

print("\nColunas do DataFrame 'new_base' após renomear:")
print(new_base.columns.tolist())

# 3. Limpeza e Transformação dos Dados

# Converter 'data_publicacao' para datetime
unimed['data_publicacao'] = pd.to_datetime(unimed['data_publicacao'], errors='coerce')
new_base['data_publicacao'] = pd.to_datetime(new_base['data_publicacao'], errors='coerce')

# Função para limpar colunas monetárias
def clean_monetary_column(column):
    def convert_value(val):
        if isinstance(val, str):
            # Remover tudo que não for número ou vírgula/ponto
            val = re.sub(r'[^\d,\.]', '', val)
            # Substituir vírgulas por pontos para converter para float
            val = val.replace(',', '.')
            try:
                return float(val)
            except:
                return np.nan
        elif isinstance(val, (int, float)):
            return float(val)
        else:
            return np.nan
    return column.apply(convert_value)

# Limpar 'valor' e 'multa' em ambos os DataFrames
unimed['valor'] = clean_monetary_column(unimed['valor'])
unimed['multa'] = clean_monetary_column(unimed['multa'])

new_base['valor'] = clean_monetary_column(new_base['valor'])
new_base['multa'] = clean_monetary_column(new_base['multa'])

# Tratar valores faltantes
unimed['multa'].fillna(0, inplace=True)
new_base['multa'].fillna(0, inplace=True)

unimed['valor'].fillna(0, inplace=True)
new_base['valor'].fillna(0, inplace=True)

# Remover linhas onde 'processo' está faltando
unimed.dropna(subset=['processo'], inplace=True)
new_base.dropna(subset=['processo'], inplace=True)

# 4. Adicionar Colunas Ausentes

# Identificar colunas exclusivas de cada DataFrame
unimed_unique = set(unimed.columns) - set(new_base.columns)
new_base_unique = set(new_base.columns) - set(unimed.columns)

# Adicionar colunas exclusivas do 'unimed' ao 'new_base' com valores NaN
for col in unimed_unique:
    new_base[col] = np.nan

# Adicionar colunas exclusivas do 'new_base' ao 'unimed' com valores NaN
for col in new_base_unique:
    unimed[col] = np.nan

# Verificar colunas duplicadas
print("\nVerificando colunas duplicadas em 'unimed':")
print(unimed.columns[unimed.columns.duplicated()].tolist())

print("\nVerificando colunas duplicadas em 'new_base':")
print(new_base.columns[new_base.columns.duplicated()].tolist())

# Remover colunas duplicadas (se houver)
unimed = unimed.loc[:, ~unimed.columns.duplicated()]
new_base = new_base.loc[:, ~new_base.columns.duplicated()]

# 5. Reorganizar as colunas

# Obter a lista de colunas únicas (sem duplicatas)
common_columns_order = unimed.columns.drop_duplicates().tolist()

# Reorganizar as colunas
unimed = unimed[common_columns_order]
new_base = new_base[common_columns_order]

# 6. Mesclar os DataFrames

# Concatenar os DataFrames
combined_df = pd.concat([unimed, new_base], ignore_index=True)

print("\nDataFrame combinado:")
print(combined_df.head())

# 7. Tratar Duplicatas

# Verificar duplicatas baseadas na coluna 'processo'
if 'processo' in combined_df.columns:
    duplicate_count = combined_df.duplicated(subset=['processo']).sum()
    print(f"\nNúmero de duplicatas encontradas com base na coluna 'processo': {duplicate_count}")

    # Remover duplicatas mantendo a primeira ocorrência
    combined_df.drop_duplicates(subset=['processo'], keep='first', inplace=True)
    print(f"Número de linhas após remover duplicatas: {combined_df.shape[0]}")
else:
    print("\nA coluna 'processo' não está presente no DataFrame combinado. Duplicatas não serão tratadas com base nesta coluna.")

# 8. Salvar o DataFrame Atualizado

combined_df.to_csv('unimed_atualizado.csv', index=False)

print("\nArquivo 'unimed_atualizado.csv' foi criado com sucesso.")
# Out:
# DataFrame 'unimed':
#            diario  ano_caderno  num_caderno            data_publicacao  \
# 0  20191029cC.txt         2019           40  2019-10-29 00:00:00+00:00
# 1   20161130I.txt         2015           59  2016-11-30 00:00:00+00:00
# 2  20181112cI.txt         2018           48  2018-11-12 00:00:00+00:00
# 3   20150505C.txt         2012          156  2015-05-05 00:00:00+00:00
# 4   20150812I.txt         2013          224  2015-08-12 00:00:00+00:00
#
#                                            vara_nome  \
# 0  *** capital conselho recursal dos jecs e jecri...
# 1                                      2a vara civel
# 2                                 1a vara de familia
# 3                                     34a vara civel
# 4                                      2a vara civel
#
#                     processo  \
# 0  0013960-09.2019.8.19.0210
# 1  0022008-23.2015.8.19.0007
# 2  0002071-08.2018.8.19.0044
# 3  0272331-71.2012.8.19.0001
# 4  0001099-27.2013.8.19.0072
#
#                                           ocorrencia  \
# 0  070. recurso inominado 0013960-09.2019.8.19.02...
# 1  proc. 0022008-23.2015.8.19.0007 - dione krull ...
# 2  proc. 0002071-08.2018.8.19.0044 - paulo sergio...
# 3  proc. 0272331-71.2012.8.19.0001 - ana paula ma...
# 4  proc. 0001099-27.2013.8.19.0072 - asafe alves ...
#
#                                                   pa  \
# 0           movimentação sem polo ativo identificado
# 1  dione krull dos santos (adv(s). dr(a). thiago ...
# 2                             paulo sergio goncalves
# 3  ana paula malta saraiva andrade dos santos (ad...
# 4  asafe alves velloso do nascimento (adv(s). dr(...
#
#                                                   pp  \
# 0         movimentação sem polo passivo identificado
# 1  unimed barra mansa (adv(s). dr(a). marcus vini...
# 2  unimed norte fluminense e outro (adv(s). dr(a)...
# 3  unimed brasilia (adv(s). dr(a). antonio carlos...
# 4     abrasf - associacao brasileira de apoio social
#
#                                                  adv  ...   ano       mes  \
# 0          oab/rj-102452;oab/rj-205703;oab/rj-202870  ...  2019   outubro
# 1  oab/rj-163009;oab/rj-200801;oab/rj-110020;oab/...  ...  2015  novembro
# 2  oab/rj-060128;oab/rj-159491;oab/rj-202952;oab/...  ...  2018  novembro
# 3                        oab/rj-112253;oab/ba-013325  ...  2012      maio
# 4                        oab/rj-174270;oab/rj-053755  ...  2013    agosto
#
#   tutela              tutela_acao  multa   valor              acao  flag  \
# 0  False  tutela não classificada    NaN  3000.0       nao provido     2
# 1  False  tutela não classificada    NaN     NaN       nao provido   111
# 2   True                   defiro    NaN     NaN  não classificado     1
# 3  False  tutela não classificada    NaN     NaN  não classificado     1
# 4  False  tutela não classificada  500.0   500.0  não classificado     1
#
#             descritor  ano_referencia
# 0      plano de saude            2019
# 1  (art.?|artigo) 196            2016
# 2      plano de saude            2018
# 3      plano de saude            2015
# 4      plano de saude            2015
#
# [5 rows x 25 columns]
#
# DataFrame 'new_base':
#            diario  num_caderno  ano_caderno data_publicacao  ano_processo  \
# 0  20201228cC.txt           77         2020      12/28/2020        2020.0
# 1  20201228cC.txt           77         2020      12/28/2020        2019.0
# 2  20200724cC.txt          212         2020       7/24/2020        2020.0
# 3  20200311cC.txt          123         2020       3/11/2020        2017.0
# 4  20200313cC.txt          125         2020       3/13/2020        2020.0
#
#         mes     descritor                   processo  \
# 0  dezembro   Azacitidina  0001332-65.2020.8.19.9000
# 1  dezembro  Bevacizumabe  0072336-30.2019.8.19.0002
# 2     julho    Rituximabe  0137111-23.2020.8.19.0001
# 3     março  Lenalidomida  0038437-70.2017.8.19.0209
# 4     março      Letrozol  0051967-81.2020.8.19.0001
#
#                                           ocorrencia  \
# 0  012. agravo de instrumento 0001332-65.2020.8.1...
# 1  054. recurso inominado 0072336-30.2019.8.19.00...
# 2  proc. 0137111-23.2020.8.19.0001 - diego aguiar...
# 3  074. recurso inominado 0038437-70.2017.8.19.02...
# 4  proc. 0051967-81.2020.8.19.0001 - andreza cava...
#
#                                         movimentacao  ...  \
# 0   oncologico origem niteroi cartorio unico jui ...  ...
# 1   medicamentos e outros insumos de saude - juiz...  ...
# 2   ..., no prazo de 10 dias, o tratamento com ri...  ...
# 3   indenizacao por dano moral - outras / indeniz...  ...
# 4   ...camentos ibrance 125 mg e letrozol 2,5mg c...  ...
#
#                                               partes  \
# 0  012. agravo de instrumento 0001332-65.2020.8.1...
# 1  054. recurso inominado 0072336-30.2019.8.19.00...
# 2  proc. 0137111-23.2020.8.19.0001 - diego aguiar...
# 3  074. recurso inominado 0038437-70.2017.8.19.02...
# 4  proc. 0051967-81.2020.8.19.0001 - andreza cava...
#
#                                          polos_geral  \
# 0  012. agravo de instrumento 0001332-65.2020.8.1...
# 1  054. recurso inominado 0072336-30.2019.8.19.00...
# 2  proc. 0137111-23.2020.8.19.0001 - diego aguiar...
# 3  074. recurso inominado 0038437-70.2017.8.19.02...
# 4  proc. 0051967-81.2020.8.19.0001 - andreza cava...
#
#                                              assunto  \
# 0  oncologico origemniteroi cartorio unico jui es...
# 1  medicamentos e outros insumos de saude - juiza...
# 2  ..., no prazo de 10 dias, o tratamento com rit...
# 3  indenizacao por dano moral - outras / indeniza...
# 4  ...camentos ibrance 125 mg e letrozol 2,5mg co...
#
#                                       assunto_agravo  \
# 0                                 oncologico origem:
# 1   medicamentos e outros insumos de saude - juiz...
# 2              movimentação sem assunto categorizado
# 3   indenizacao por dano moral - outras / indeniz...
# 4              movimentação sem assunto categorizado
#
#                             multas                      valor  \
# 0     movimentacao sem valor(0)(0)  movimentacao sem valor(0)
# 1     movimentacao sem valor(0)(0)  movimentacao sem valor(0)
# 2  c(" r$ 500,00", "r$ 80.000,00")  movimentacao sem valor(0)
# 3     movimentacao sem valor(0)(0)  movimentacao sem valor(0)
# 4                         r$500,00                     500,00
#
#                                               tutela  \
# 0                                         antecipada
# 1  mente significativo com baixa acuidade visual ...
# 2                  movimentação sem tutela apreciada
# 3  mente o principio da oralidade, frisando-se, o...
# 4                  movimentação sem tutela apreciada
#
#                                                  oab tempo_processo  \
# 0  oab/rj-155684 ab/tj-000009  ab/rj-202905 ab/rj...            0.0
# 1                       oab/tj-000007  ab/tj-000002             1.0
# 2  oab/rj-095701, oab/rj-211560, oab/tj-000002, o...            0.0
# 3            oab/rj-114322 ab/rj-080687 ab/rj-118911            3.0
# 4                                      oab/rj-181153            0.0
#
#   tempo_processo_mes
# 0                0.0
# 1               12.0
# 2                0.0
# 3               36.0
# 4                0.0
#
# [5 rows x 22 columns]
#
# Colunas do DataFrame 'unimed':
# ['diario', 'ano_caderno', 'num_caderno', 'data_publicacao', 'vara_nome', 'processo', 'ocorrencia', 'pa', 'pp', 'adv', 'tempo_processo_mes', 'tempo_processo_ano', 'tipo', 'assunto_agravo', 'movimentacao', 'ano', 'mes', 'tutela', 'tutela_acao', 'multa', 'valor', 'acao', 'flag', 'descritor', 'ano_referencia']
#
# Colunas do DataFrame 'new_base' antes de renomear:
# ['diario', 'num_caderno', 'ano_caderno', 'data_publicacao', 'ano_processo', 'mes', 'descritor', 'processo', 'ocorrencia', 'movimentacao', 'vara_nome', 'tipo', 'partes', 'polos_geral', 'assunto', 'assunto_agravo', 'multas', 'valor', 'tutela', 'oab', 'tempo_processo', 'tempo_processo_mes']
#
# Colunas do DataFrame 'new_base' após renomear:
# ['diario', 'num_caderno', 'ano_caderno', 'data_publicacao', 'ano_referencia', 'mes', 'descritor', 'processo', 'ocorrencia', 'movimentacao', 'vara_nome', 'tipo', 'partes', 'polos_geral', 'assunto_agravo', 'assunto_agravo', 'multa', 'valor', 'tutela', 'adv', 'tempo_processo', 'tempo_processo_mes']
# /var/folders/ql/97jfk1x152v1dwrlkfh3vft00000gn/T/ipykernel_27983/3228393885.py:66: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   unimed['multa'].fillna(0, inplace=True)
# /var/folders/ql/97jfk1x152v1dwrlkfh3vft00000gn/T/ipykernel_27983/3228393885.py:67: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   new_base['multa'].fillna(0, inplace=True)
# /var/folders/ql/97jfk1x152v1dwrlkfh3vft00000gn/T/ipykernel_27983/3228393885.py:69: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   unimed['valor'].fillna(0, inplace=True)
# /var/folders/ql/97jfk1x152v1dwrlkfh3vft00000gn/T/ipykernel_27983/3228393885.py:70: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   new_base['valor'].fillna(0, inplace=True)
# Verificando colunas duplicadas em 'unimed':
# []
#
# Verificando colunas duplicadas em 'new_base':
# ['assunto_agravo']
#
# DataFrame combinado:
#            diario  ano_caderno  num_caderno            data_publicacao  \
# 0  20191029cC.txt         2019           40  2019-10-29 00:00:00+00:00
# 1   20161130I.txt         2015           59  2016-11-30 00:00:00+00:00
# 2  20181112cI.txt         2018           48  2018-11-12 00:00:00+00:00
# 3   20150505C.txt         2012          156  2015-05-05 00:00:00+00:00
# 4   20150812I.txt         2013          224  2015-08-12 00:00:00+00:00
#
#                                            vara_nome  \
# 0  *** capital conselho recursal dos jecs e jecri...
# 1                                      2a vara civel
# 2                                 1a vara de familia
# 3                                     34a vara civel
# 4                                      2a vara civel
#
#                     processo  \
# 0  0013960-09.2019.8.19.0210
# 1  0022008-23.2015.8.19.0007
# 2  0002071-08.2018.8.19.0044
# 3  0272331-71.2012.8.19.0001
# 4  0001099-27.2013.8.19.0072
#
#                                           ocorrencia  \
# 0  070. recurso inominado 0013960-09.2019.8.19.02...
# 1  proc. 0022008-23.2015.8.19.0007 - dione krull ...
# 2  proc. 0002071-08.2018.8.19.0044 - paulo sergio...
# 3  proc. 0272331-71.2012.8.19.0001 - ana paula ma...
# 4  proc. 0001099-27.2013.8.19.0072 - asafe alves ...
#
#                                                   pa  \
# 0           movimentação sem polo ativo identificado
# 1  dione krull dos santos (adv(s). dr(a). thiago ...
# 2                             paulo sergio goncalves
# 3  ana paula malta saraiva andrade dos santos (ad...
# 4  asafe alves velloso do nascimento (adv(s). dr(...
#
#                                                   pp  \
# 0         movimentação sem polo passivo identificado
# 1  unimed barra mansa (adv(s). dr(a). marcus vini...
# 2  unimed norte fluminense e outro (adv(s). dr(a)...
# 3  unimed brasilia (adv(s). dr(a). antonio carlos...
# 4     abrasf - associacao brasileira de apoio social
#
#                                                  adv  ...  \
# 0          oab/rj-102452;oab/rj-205703;oab/rj-202870  ...
# 1  oab/rj-163009;oab/rj-200801;oab/rj-110020;oab/...  ...
# 2  oab/rj-060128;oab/rj-159491;oab/rj-202952;oab/...  ...
# 3                        oab/rj-112253;oab/ba-013325  ...
# 4                        oab/rj-174270;oab/rj-053755  ...
#
#                tutela_acao  multa   valor              acao   flag  \
# 0  tutela não classificada    0.0  3000.0       nao provido    2.0
# 1  tutela não classificada    0.0     0.0       nao provido  111.0
# 2                   defiro    0.0     0.0  não classificado    1.0
# 3  tutela não classificada    0.0     0.0  não classificado    1.0
# 4  tutela não classificada  500.0   500.0  não classificado    1.0
#
#             descritor ano_referencia tempo_processo polos_geral  partes
# 0      plano de saude         2019.0            NaN         NaN     NaN
# 1  (art.?|artigo) 196         2016.0            NaN         NaN     NaN
# 2      plano de saude         2018.0            NaN         NaN     NaN
# 3      plano de saude         2015.0            NaN         NaN     NaN
# 4      plano de saude         2015.0            NaN         NaN     NaN
#
# [5 rows x 28 columns]
#
# Número de duplicatas encontradas com base na coluna 'processo': 1647
# Número de linhas após remover duplicatas: 3086
#
# Arquivo 'unimed_atualizado.csv' foi criado com sucesso.

# %%
combined_df['descritor'].unique()
# Out:
# array(['plano de saude', '(art.?|artigo) 196', 'cancer', 'leito uti',
#        'quimioterapia',
#        'direito ao? (assistencia farmaceutica|assistencia medica|internacao|saude|vida|tratamento|medicamento)',
#        'internacao hospitalar', 'Procarbazina', 'tratamento hormonal',
#        'Crizotinibe', 'Rituximabe', 'radioterapia', 'BIÓPSIA',
#        'Tocilizumabe', 'transplante de medula', 'cancer de mama',
#        'leucemia', 'neoplasia maligna', 'negativa de tratamento',
#        'ATENÇÃO À SAUDE', 'linfoma', 'Carboplatina',
#        'custo do tratamento', 'adenocarcinoma', 'origem da molestia',
#        'sistema unico de saude', 'Azacitidina', 'Bevacizumabe',
#        'Lenalidomida', 'Letrozol', 'Ciproterona', 'Ipilimumabe',
#        'Dexametasona', 'Bendamustina', 'Brentuximabe Vedotina',
#        'Pertuzumabe', 'Imatinibe', 'Mesna', 'Vemurafenibe', 'Docetaxel',
#        'Capecitabina', 'Filgrastim', 'Etoposídeo', 'saude publica',
#        '(art\\.?|artigo) 196', 'rede publica de saude',
#        'custo do medicamento', 'servico hospitalar', 'combate ao cancer',
#        'uso off label', 'betaterapia', 'garantir o tratamento',
#        'progressao do quadro',
#        'assunto: medicamentos e outros insumos de saude - juizados fazendarios / fornecimento de medicamentos / saude / servicos / direito administrativo e outras materias de direito publico',
#        'Atenção Básica', 'medicamentos e insumos'], dtype=object)

# %%
import pandas as pd

# Carregar o CSV sem parsing de datas
unimed_df = pd.read_csv('unimed_atualizado.csv')

# Verificar os tipos de dados
print(unimed_df.dtypes)
# Out:
# diario                 object
# ano_caderno             int64
# num_caderno             int64
# data_publicacao        object
# vara_nome              object
# processo               object
# ocorrencia             object
# pa                     object
# pp                     object
# adv                    object
# tempo_processo_mes    float64
# tempo_processo_ano    float64
# tipo                   object
# assunto_agravo         object
# movimentacao           object
# ano                   float64
# mes                    object
# tutela                 object
# tutela_acao            object
# multa                 float64
# valor                 float64
# acao                   object
# flag                  float64
# descritor              object
# ano_referencia        float64
# tempo_processo        float64
# polos_geral            object
# partes                 object
# dtype: object

# %%
# Tentar converter 'data_publicacao' para datetime e identificar erros
unimed_df['data_publicacao_converted'] = pd.to_datetime(unimed_df['data_publicacao'], errors='coerce')

# Identificar linhas com valores NaT (Not a Time) após a conversão
invalid_dates = unimed_df[unimed_df['data_publicacao_converted'].isna()]
print("Linhas com datas inválidas:")
print(invalid_dates)
# Out:
# Linhas com datas inválidas:
#               diario  ano_caderno  num_caderno      data_publicacao  \
# 762   20201228cC.txt         2020           77  2020-12-28 00:00:00
# 763   20201228cC.txt         2020           77  2020-12-28 00:00:00
# 764   20200724cC.txt         2020          212  2020-07-24 00:00:00
# 765   20200311cC.txt         2020          123  2020-03-11 00:00:00
# 766   20200313cC.txt         2020          125  2020-03-13 00:00:00
# ...              ...          ...          ...                  ...
# 3081  20201006cC.txt         2020           25  2020-10-06 00:00:00
# 3082  20200807cC.txt         2020          222  2020-08-07 00:00:00
# 3083  20201204cC.txt         2020           64  2020-12-04 00:00:00
# 3084  20200921cC.txt         2020           14  2020-09-21 00:00:00
# 3085  20200219cC.txt         2020          112  2020-02-19 00:00:00
#
#                                          vara_nome                   processo  \
# 762   capital conselho recursal dos jecs e jecrims  0001332-65.2020.8.19.9000
# 763   capital conselho recursal dos jecs e jecrims  0072336-30.2019.8.19.0002
# 764                                  4a vara civel  0137111-23.2020.8.19.0001
# 765   capital conselho recursal dos jecs e jecrims  0038437-70.2017.8.19.0209
# 766                                 39a vara civel  0051967-81.2020.8.19.0001
# ...                                            ...                        ...
# 3081                           6a vara empresarial  0002895-88.2017.8.19.0209
# 3082  capital conselho recursal dos jecs e jecrims  0012243-42.2019.8.19.0054
# 3083                            1a vara de familia  0035404-98.2014.8.19.0202
# 3084                                29a vara civel  0219729-06.2012.8.19.0001
# 3085                                 1a vara civel  0073598-52.2018.8.19.0001
#
#                                              ocorrencia   pa   pp  \
# 762   012. agravo de instrumento 0001332-65.2020.8.1...  NaN  NaN
# 763   054. recurso inominado 0072336-30.2019.8.19.00...  NaN  NaN
# 764   proc. 0137111-23.2020.8.19.0001 - diego aguiar...  NaN  NaN
# 765   074. recurso inominado 0038437-70.2017.8.19.02...  NaN  NaN
# 766   proc. 0051967-81.2020.8.19.0001 - andreza cava...  NaN  NaN
# ...                                                 ...  ...  ...
# 3081  proc. 0002895-88.2017.8.19.0209 - rosineide ma...  NaN  NaN
# 3082  462. recurso inominado 0012243-42.2019.8.19.00...  NaN  NaN
# 3083  proc. 0035404-98.2014.8.19.0202 - p.m.n.j. e o...  NaN  NaN
# 3084  proc. 0219729-06.2012.8.19.0001 - rufolo empre...  NaN  NaN
# 3085  proc. 0073598-52.2018.8.19.0001 - cns nacional...  NaN  NaN
#
#                                                     adv  ...  multa  valor  \
# 762   oab/rj-155684 ab/tj-000009  ab/rj-202905 ab/rj...  ...    0.0    0.0
# 763                        oab/tj-000007  ab/tj-000002   ...    0.0    0.0
# 764   oab/rj-095701, oab/rj-211560, oab/tj-000002, o...  ...    0.0    0.0
# 765             oab/rj-114322 ab/rj-080687 ab/rj-118911  ...    0.0    0.0
# 766                                       oab/rj-181153  ...  500.0  500.0
# ...                                                 ...  ...    ...    ...
# 3081                                      oab/rj-208885  ...    0.0    0.0
# 3082            oab/rj-189639 ab/rj-172192 ab/rj-152191  ...    0.0    0.0
# 3083                       oab/rj-156477, oab/rj-119789  ...    0.0    0.0
# 3084        oab/rj-148584, oab/rj-109339, oab/rj-109734  ...    0.0    0.0
# 3085                       oab/rj-201298, oab/rj-213445  ...    0.0    0.0
#
#      acao flag        descritor  ano_referencia tempo_processo  \
# 762   NaN  NaN      Azacitidina          2020.0            0.0
# 763   NaN  NaN     Bevacizumabe          2019.0            1.0
# 764   NaN  NaN       Rituximabe          2020.0            0.0
# 765   NaN  NaN     Lenalidomida          2017.0            3.0
# 766   NaN  NaN         Letrozol          2020.0            0.0
# ...   ...  ...              ...             ...            ...
# 3081  NaN  NaN   Atenção Básica          2017.0            3.0
# 3082  NaN  NaN   Atenção Básica          2019.0            1.0
# 3083  NaN  NaN  ATENÇÃO À SAUDE          2014.0            6.0
# 3084  NaN  NaN   Atenção Básica          2012.0            8.0
# 3085  NaN  NaN   Atenção Básica          2018.0            2.0
#
#                                             polos_geral  \
# 762   012. agravo de instrumento 0001332-65.2020.8.1...
# 763   054. recurso inominado 0072336-30.2019.8.19.00...
# 764   proc. 0137111-23.2020.8.19.0001 - diego aguiar...
# 765   074. recurso inominado 0038437-70.2017.8.19.02...
# 766   proc. 0051967-81.2020.8.19.0001 - andreza cava...
# ...                                                 ...
# 3081  0002895-88.2017.8.19.0209 - rosineide marcelin...
# 3082  - outras / indenizacao por dano moral / respon...
# 3083  proc. 0035404-98.2014.8.19.0202 - p.m.n.j. e o...
# 3084  - rufolo empresa de servicos tecnicos e constr...
# 3085  proc. 0073598-52.2018.8.19.0001 - cns nacional...
#
#                                                  partes  \
# 762   012. agravo de instrumento 0001332-65.2020.8.1...
# 763   054. recurso inominado 0072336-30.2019.8.19.00...
# 764   proc. 0137111-23.2020.8.19.0001 - diego aguiar...
# 765   074. recurso inominado 0038437-70.2017.8.19.02...
# 766   proc. 0051967-81.2020.8.19.0001 - andreza cava...
# ...                                                 ...
# 3081  proc. 0002895-88.2017.8.19.0209 - rosineide ma...
# 3082  462. recurso inominado 0012243-42.2019.8.19.00...
# 3083  proc. 0035404-98.2014.8.19.0202 - p.m.n.j. e o...
# 3084  proc. 0219729-06.2012.8.19.0001 - rufolo empre...
# 3085  proc. 0073598-52.2018.8.19.0001 - cns nacional...
#
#       data_publicacao_converted
# 762                         NaT
# 763                         NaT
# 764                         NaT
# 765                         NaT
# 766                         NaT
# ...                         ...
# 3081                        NaT
# 3082                        NaT
# 3083                        NaT
# 3084                        NaT
# 3085                        NaT
#
# [2324 rows x 29 columns]

# %%
# Função para tentar diferentes formatos de data
def parse_dates(date_str):
    for fmt in ('%Y-%m-%d %H:%M:%S%z', '%Y-%m-%d %H:%M:%S', '%Y%m%d'):
        try:
            return pd.to_datetime(date_str, format=fmt, utc=True)
        except (ValueError, TypeError):
            continue
    return pd.NaT  # Retorna NaT se nenhum formato corresponder

# Aplicar a função de parsing
unimed_df['data_publicacao_converted'] = unimed_df['data_publicacao'].apply(parse_dates)

# Remover linhas com datas ainda inválidas após tentativa de correção
unimed_df_cleaned = unimed_df.dropna(subset=['data_publicacao_converted']).copy()

# Substituir a coluna original pela coluna convertida
unimed_df_cleaned['data_publicacao'] = unimed_df_cleaned['data_publicacao_converted']

# Remover a coluna auxiliar
unimed_df_cleaned.drop(columns=['data_publicacao_converted'], inplace=True)

# %%
print(unimed_df_cleaned.dtypes)
# Out:
# diario                             object
# ano_caderno                         int64
# num_caderno                         int64
# data_publicacao       datetime64[ns, UTC]
# vara_nome                          object
# processo                           object
# ocorrencia                         object
# pa                                 object
# pp                                 object
# adv                                object
# tempo_processo_mes                float64
# tempo_processo_ano                float64
# tipo                               object
# assunto_agravo                     object
# movimentacao                       object
# ano                               float64
# mes                                object
# tutela                             object
# tutela_acao                        object
# multa                             float64
# valor                             float64
# acao                               object
# flag                              float64
# descritor                          object
# ano_referencia                    float64
# tempo_processo                    float64
# polos_geral                        object
# partes                             object
# dtype: object

# %%
# Exportar o DataFrame limpo para um novo CSV
unimed_df_cleaned.to_csv('unimed_atualizado_cleaned.csv', index=False)
